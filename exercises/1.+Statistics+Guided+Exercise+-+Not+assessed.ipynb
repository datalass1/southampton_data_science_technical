# %% [markdown]
# # Statistics Guided Exercise
#
# For using statistics with Python, we will be looking at the Pandas library.  Pandas itself is built on top of another library, NumPy, and both have their own data structures.  In this exercise, we will go over these data structures, and introduce you to Bokeh, which is a visualisation library you will be using in this exercise and the next for graphs and charts.

# %% [markdown]
# ## Pandas
#
# Pandas is a Python library for data analysis in Python.  It providies some useful functions and data structures for the collection and analysis of data.  In particular, we will be making use of the **`DataFrame`** and **`Series`** classes.
#
# A `DataFrame` object represents data in a series of rows (individual observations of data) and columns (features or variables) within those data.  Each of those rows and columns can be extracted, and they then become a `Series`.  We will work through an example to illustrate these concepts.
#
# ### Importing Data
#
# There are convenience functions to import data, such as **`read_json`** and **`read_csv`** which, as their names suggest, will import data which is already in a particular format.  For this example, we will import data from the MongoDB database we used in the exercise last week.
#
# For this example, we will import the first 1000 documents (*MongoDB stores data records as BSON documents. BSON is a binary representation of JSON documents, though it contains more data types than JSON*), in the UK collection into a Pandas `DataFrame`.  Run the cell below

# %%
# Convention is to import numpy and pandas with abbreviated names
# This means that instead of using pandas.read_csv, you would use pd.read_csv
import numpy as np
import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.charts import *

# Import PyMongo, so that we can query some data
# 'mongodb://cpduser:M13pV5woDW@mongodb/health_data' is the location of the data we will be using

from pymongo import MongoClient
client = MongoClient('mongodb://cpduser:M13pV5woDW@mongodb/health_data') 
#location is a database stored on course server
db = client.health_data

cursor = db.uk.find({'RatingValue': {'$ne': None}}).limit(1000)
#$ne selects the documents where the value of the field is not equal to the specified value. 
#This query will select all documents in the collection where the 'RatingValue' field value does not equal None.

# Unfortunately, Pandas does not support PyMongo objects for import, so we need to cast it to a list
listy = list(cursor)

# Create a Pandas DataFrame with the list object as a parameter
first_1000 = pd.DataFrame(listy)

# %% [markdown]
# Now we have our imported data in a **`DataFrame` object**.  Like any other Python object, it has a collection of attributes and methods which we can use.  We will go over some here, but see [the documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) for a full list.  We'll start by seeing what the data looks like by calling the `head()` function on the data:

# %%
# return the first five reocrds in the dataset
first_1000.head()

print(first_1000.columns)
# Try filtering the data in the DataFrame to only return rows where RatingValue < 3 by uncommenting the following line
# of code
first_1000[first_1000['RatingValue'] < 3]

# is the result as you would expect?
# Out:
# Index(['AddressLine1', 'AddressLine2', 'AddressLine3', 'AddressLine4',
#        'BusinessName', 'BusinessType', 'BusinessTypeID',
#        'ConfidenceInManagement', 'FHRSID', 'Geocode', 'Hygiene', 'Lat', 'Lng',
#        'LocalAuthorityBusinessID', 'LocalAuthorityCode',
#        'LocalAuthorityEmailAddress', 'LocalAuthorityName',
#        'LocalAuthorityWebSite', 'NewRatingPending', 'PostCode', 'RatingDate',
#        'RatingKey', 'RatingValue', 'Region', 'SchemeType', 'Scores',
#        'Structural', '_id'],
#       dtype='object')
#                             AddressLine1        AddressLine2 AddressLine3  \
# 17                         Denmark House    220 Denmark Road    Lowestoft
# 47                             2 Hungate             Beccles      Suffolk
# 48                 6 Upper Olland Street              Bungay      Suffolk
# 113                     1 Mount Pleasant              Reydon    Southwold
# 120                    8 Commercial Road           Lowestoft      Suffolk
# 151                        Putting Green        North Parade    Southwold
# 163                   63 Westwood Avenue           Lowestoft      Suffolk
# 171                      28 Carlton Road           Lowestoft      Suffolk
# 184                    13 Station Square           Lowestoft      Suffolk
# 250                       16 Snape Drive           Lowestoft      Suffolk
# 254                                  NaN                 NaN          NaN
# 264                    32 Rotterdam Road           Lowestoft      Suffolk
# 282                105 - 106 High Street           Lowestoft      Suffolk
# 299                       77 High Street           Southwold      Suffolk
# 302                 10 Bevan Street East           Lowestoft      Suffolk
# 308                       Five Bells Inn      Southwold Road     Wrentham
# 402                   The Hotel Victoria  Kirkley Cliff Road    Lowestoft
# 422                      151 High Street           Lowestoft      Suffolk
# 438                  28 Wingfield Street              Bungay      Suffolk
# 444                49 Kirkley Cliff Road           Lowestoft      Suffolk
# 458                138 London Road South           Lowestoft      Suffolk
# 470                     77 Raglan Street           Lowestoft      Suffolk
# 478                        4 Whites Lane         Kessingland    Lowestoft
# 493                 18 - 20 Norwich Road           Lowestoft      Suffolk
# 530                     Manor Farm House      82 Church Road  Kessingland
# 551                       73 High Street           Lowestoft      Suffolk
# 552                      50 Thoroughfare          Halesworth      Suffolk
# 583                         67 Love Road           Lowestoft      Suffolk
# 585                   72 Halesworth Road              Reydon    Southwold
# 587                 4 The Britten Centre   London Road North    Lowestoft
# 612                   6 Nightingale Road           Lowestoft      Suffolk
# 616                 The Olde Barn Bakery            Buck Inn   The Street
# 643                            Park Hill              Oulton    Lowestoft
# 654                         3 Blyburgate             Beccles      Suffolk
# 656                     8 Imperial House        Denmark Road    Lowestoft
# 699                        37 Ravensmere             Beccles      Suffolk
# 729                     The Sailors Home     302 Church Road  Kessingland
# 739                        14 Cooke Road            Gisleham    Lowestoft
# 766  Pleasurewood Hills American Theme P         Leisure Way    Lowestoft
# 821                      10 Carlton Road           Lowestoft      Suffolk
# 890                         Fleece Hotel     St Marys Street       Bungay
# 931                        2 Regent Road           Lowestoft      Suffolk
# 932                  1 - 2 Yacht Station       The Boulevard    Lowestoft
# 938                  85 - 86 High Street           Lowestoft      Suffolk
# 956                         Haven Marina         School Road    Lowestoft
# 968                               Unit 1  6 Milton Road East    Lowestoft
# 986                     17 The Esplanade           Lowestoft      Suffolk
#
#      AddressLine4                        BusinessName  \
# 17        Suffolk              Access Community Trust
# 47            NaN                  Baileys Delitessen
# 48            NaN                    Bairds Of Bungay
# 113       Suffolk                      Boydens Stores
# 120           NaN          Bridge View Drop-in Centre
# 151       Suffolk                   Cafe On The Green
# 163           NaN            Capital Chinese Takeaway
# 171           NaN                 Carlton Road Stores
# 184           NaN                      Charcoal Grill
# 250           NaN                       Dylann's News
# 254           NaN      East Coast Cakes And Preserves
# 264           NaN                   Eddie's Mini Mart
# 282           NaN          Emperor Chinese Restaurant
# 299           NaN                    Farmhouse Bakery
# 302           NaN                   Farzana Spice Ltd
# 308       Beccles                          Five Bells
# 402       Suffolk                      Hotel Victoria
# 422           NaN                       Istanbul Chef
# 438           NaN                          John Groom
# 444           NaN                     Katherine Hotel
# 458           NaN               Kings Kebab And Pizza
# 470           NaN                             Lan Tin
# 478       Suffolk                  Leon's Eatries Ltd
# 493           NaN                              Londis
# 530     Lowestoft                          Manor Farm
# 551           NaN           Mediterranean Kebab House
# 552           NaN                  Melons Greengrocer
# 583           NaN                        New Shanghai
# 585       Suffolk              Newlands Country House
# 587       Suffolk                      Nicholls Meats
# 612           NaN                     Oddfellows Arms
# 616  Flixton West                    Olde Barn Bakery
# 643       Suffolk                     Park Hill Hotel
# 654           NaN                         Pearl River
# 656       Suffolk                  Perfect Pizza Plus
# 699           NaN             Ravensmere Fish & Chips
# 729     Lowestoft                        Sailors Home
# 739       Suffolk                              Scotts
# 766       Suffolk                        Smokey Joe's
# 821           NaN       Stradbrokes & Kirkley Florist
# 890       Suffolk                      The Fleece Inn
# 931           NaN                The Poppies Tearooms
# 932       Suffolk                           The Quays
# 938           NaN  The Royal Tawa Tandoori Restaurant
# 956       Suffolk                  The Third Crossing
# 968       Suffolk                    The Unity Centre
# 986           NaN                         Tides Reach
#
#                             BusinessType BusinessTypeID  \
# 17   Hospitals/Childcare/Caring Premises              5
# 47               Restaurant/Cafe/Canteen              1
# 48                     Retailers - other           4613
# 113                    Retailers - other           4613
# 120              Restaurant/Cafe/Canteen              1
# 151              Restaurant/Cafe/Canteen              1
# 163               Takeaway/sandwich shop           7844
# 171                    Retailers - other           4613
# 184               Takeaway/sandwich shop           7844
# 250                    Retailers - other           4613
# 254                    Retailers - other           4613
# 264                    Retailers - other           4613
# 282              Restaurant/Cafe/Canteen              1
# 299                    Retailers - other           4613
# 302               Takeaway/sandwich shop           7844
# 308                    Pub/bar/nightclub           7843
# 402    Hotel/bed & breakfast/guest house           7842
# 422               Takeaway/sandwich shop           7844
# 438                    Retailers - other           4613
# 444    Hotel/bed & breakfast/guest house           7842
# 458               Takeaway/sandwich shop           7844
# 470               Takeaway/sandwich shop           7844
# 478                    Pub/bar/nightclub           7843
# 493                    Retailers - other           4613
# 530  Hospitals/Childcare/Caring Premises              5
# 551               Takeaway/sandwich shop           7844
# 552                    Retailers - other           4613
# 583               Takeaway/sandwich shop           7844
# 585    Hotel/bed & breakfast/guest house           7842
# 587                    Retailers - other           4613
# 612                    Pub/bar/nightclub           7843
# 616                Manufacturers/packers           7839
# 643    Hotel/bed & breakfast/guest house           7842
# 654               Takeaway/sandwich shop           7844
# 656               Takeaway/sandwich shop           7844
# 699               Takeaway/sandwich shop           7844
# 729                    Pub/bar/nightclub           7843
# 739              Restaurant/Cafe/Canteen              1
# 766               Takeaway/sandwich shop           7844
# 821                    Retailers - other           4613
# 890    Hotel/bed & breakfast/guest house           7842
# 931              Restaurant/Cafe/Canteen              1
# 932              Restaurant/Cafe/Canteen              1
# 938              Restaurant/Cafe/Canteen              1
# 956              Restaurant/Cafe/Canteen              1
# 968              Restaurant/Cafe/Canteen              1
# 986              Restaurant/Cafe/Canteen              1
#
#      ConfidenceInManagement  FHRSID  \
# 17                     20.0  743308
# 47                     10.0  275470
# 48                     10.0  275565
# 113                    20.0  275772
# 120                    20.0  275152
# 151                    20.0  690379
# 163                    10.0  275438
# 171                    20.0  275136
# 184                    20.0  275247
# 250                    20.0  275405
# 254                    20.0  780961
# 264                    10.0  275375
# 282                    10.0  275996
# 299                    10.0  842935
# 302                    10.0  275099
# 308                    20.0  275785
# 402                    10.0  275239
# 422                    20.0  275214
# 438                    10.0  275567
# 444                    20.0  275236
# 458                    10.0  275297
# 470                    10.0  275368
# 478                    10.0  275746
# 493                    20.0  275340
# 530                     5.0  275734
# 551                    20.0  275201
# 552                     5.0  275603
# 583                    20.0  275316
# 585                    20.0  481032
# 587                    20.0  804010
# 612                    20.0  275336
# 616                    20.0  275858
# 643                    10.0  275763
# 654                    20.0  275452
# 656                    10.0  275164
# 699                    20.0  275498
# 729                    20.0  275731
# 739                    10.0  716558
# 766                    10.0  275933
# 821                    10.0  275135
# 890                    20.0  275556
# 931                    10.0  276048
# 932                    20.0  275112
# 938                    20.0  275202
# 956                    10.0  275904
# 968                    20.0  401859
# 986                    10.0  275169
#
#                                                Geocode  \
# 17   {'coordinates': [1.740587, 52.475446], 'type':...
# 47   {'coordinates': [1.563638, 52.456576], 'type':...
# 48   {'coordinates': [1.437991, 52.453769], 'type':...
# 113  {'coordinates': [1.670424, 52.340926], 'type':...
# 120  {'coordinates': [1.748485, 52.47391], 'type': ...
# 151                                               None
# 163  {'coordinates': [1.717385, 52.463037], 'type':...
# 171  {'coordinates': [1.741089, 52.46505], 'type': ...
# 184  {'coordinates': [1.75006, 52.473896], 'type': ...
# 250  {'coordinates': [1.725121, 52.490606], 'type':...
# 254                                               None
# 264  {'coordinates': [1.738361, 52.478899], 'type':...
# 282  {'coordinates': [1.756476, 52.482984], 'type':...
# 299  {'coordinates': [1.678384, 52.326259], 'type':...
# 302  {'coordinates': [1.749566, 52.475018], 'type':...
# 308  {'coordinates': [1.670846, 52.381596], 'type':...
# 402  {'coordinates': [1.742745, 52.463559], 'type':...
# 422  {'coordinates': [1.755675, 52.482047], 'type':...
# 438  {'coordinates': [1.442307, 52.453041], 'type':...
# 444  {'coordinates': [1.73949, 52.460783], 'type': ...
# 458  {'coordinates': [1.74582, 52.468381], 'type': ...
# 470  {'coordinates': [1.748995, 52.478175], 'type':...
# 478  {'coordinates': [1.7068, 52.418584], 'type': '...
# 493  {'coordinates': [1.744289, 52.477056], 'type':...
# 530  {'coordinates': [1.713772, 52.416638], 'type':...
# 551  {'coordinates': [1.755845, 52.480935], 'type':...
# 552  {'coordinates': [1.501789, 52.343828], 'type':...
# 583  {'coordinates': [1.749327, 52.47982], 'type': ...
# 585  {'coordinates': [1.661378, 52.335603], 'type':...
# 587  {'coordinates': [1.751636, 52.47667], 'type': ...
# 612  {'coordinates': [1.733541, 52.451572], 'type':...
# 616  {'coordinates': [1.401294, 52.435323], 'type':...
# 643  {'coordinates': [1.721001, 52.49678], 'type': ...
# 654  {'coordinates': [1.564248, 52.456657], 'type':...
# 656  {'coordinates': [1.74608, 52.475083], 'type': ...
# 699  {'coordinates': [1.564901, 52.461449], 'type':...
# 729  {'coordinates': [1.72654, 52.4128], 'type': 'P...
# 739  {'coordinates': [1.719483, 52.446879], 'type':...
# 766  {'coordinates': [1.744757, 52.506814], 'type':...
# 821  {'coordinates': [1.741089, 52.46505], 'type': ...
# 890  {'coordinates': [1.437557, 52.454807], 'type':...
# 931  {'coordinates': [1.752483, 52.477957], 'type':...
# 932  {'coordinates': [1.709091, 52.472275], 'type':...
# 938  {'coordinates': [1.755845, 52.480935], 'type':...
# 956  {'coordinates': [1.720928, 52.472199], 'type':...
# 968  {'coordinates': [1.753371, 52.478873], 'type':...
# 986  {'coordinates': [1.747, 52.468407], 'type': 'P...
#
#                ...             NewRatingPending  PostCode  RatingDate  \
# 17             ...                        False  NR32 2EN  2015-03-18
# 47             ...                        False  NR34 9TL  2016-02-01
# 48             ...                        False  NR35 1BG  2015-08-25
# 113            ...                        False  IP18 6QG  2016-03-07
# 120            ...                        False  NR32 2TD  2015-02-23
# 151            ...                         True       NaN  2016-04-04
# 163            ...                        False  NR33 9RW  2016-08-03
# 171            ...                        False  NR33 0RY  2015-12-15
# 184            ...                        False  NR32 1BA  2016-05-31
# 250            ...                        False  NR32 4SF  2016-01-04
# 254            ...                        False       NaN  2015-07-27
# 264            ...                        False  NR32 2HA  2015-08-05
# 282            ...                        False  NR32 1HZ  2015-05-19
# 299            ...                        False  IP18 6DS  2016-02-27
# 302            ...                        False  NR32 2AA  2015-06-12
# 308            ...                        False  NR34 7JF  2016-02-26
# 402            ...                        False  NR33 0BZ  2016-02-27
# 422            ...                        False  NR32 1HR  2016-05-31
# 438            ...                        False  NR35 1EZ  2016-03-10
# 444            ...                        False  NR33 0DF  2016-05-11
# 458            ...                        False  NR33 0AZ  2016-07-07
# 470            ...                        False  NR32 2JU  2016-03-31
# 478            ...                        False  NR33 7TF  2015-12-03
# 493            ...                        False  NR32 2BW  2015-05-05
# 530            ...                        False  NR33 7SJ  2016-07-04
# 551            ...                        False  NR32 1XN  2016-08-03
# 552            ...                        False  IP19 8AR  2016-02-24
# 583            ...                        False  NR32 2NZ  2015-08-12
# 585            ...                        False  IP18 6NS  2016-06-30
# 587            ...                        False  NR32 1LR  2016-05-18
# 612            ...                        False  NR33 7AU  2016-03-02
# 616            ...                        False  NR35 1NZ  2015-09-30
# 643            ...                        False  NR32 3BL  2015-11-10
# 654            ...                        False  NR34 9TA  2016-07-06
# 656            ...                        False  NR32 2EH  2016-01-29
# 699            ...                        False  NR34 9DH  2016-04-06
# 729            ...                        False  NR33 7SB  2016-02-22
# 739            ...                        False  NR33 7NA  2016-08-09
# 766            ...                        False  NR32 5DZ  2016-08-08
# 821            ...                        False  NR33 0RY  2016-02-15
# 890            ...                        False  NR35 1AX  2016-02-15
# 931            ...                        False  NR32 1PA  2015-09-23
# 932            ...                        False  NR33 9JU  2015-09-02
# 938            ...                        False  NR32 1XN  2016-04-13
# 956            ...                        False  NR33 9NB  2016-03-05
# 968            ...                        False  NR32 1NT  2015-07-29
# 986            ...                        False  NR33 0QG  2016-08-17
#
#         RatingKey RatingValue         Region SchemeType  \
# 17   fhrs_1_en-GB           1  east_counties       FHRS
# 47   fhrs_2_en-GB           2  east_counties       FHRS
# 48   fhrs_2_en-GB           2  east_counties       FHRS
# 113  fhrs_1_en-GB           1  east_counties       FHRS
# 120  fhrs_1_en-GB           1  east_counties       FHRS
# 151  fhrs_1_en-GB           1  east_counties       FHRS
# 163  fhrs_2_en-GB           2  east_counties       FHRS
# 171  fhrs_1_en-GB           1  east_counties       FHRS
# 184  fhrs_1_en-GB           1  east_counties       FHRS
# 250  fhrs_1_en-GB           1  east_counties       FHRS
# 254  fhrs_1_en-GB           1  east_counties       FHRS
# 264  fhrs_2_en-GB           2  east_counties       FHRS
# 282  fhrs_2_en-GB           2  east_counties       FHRS
# 299  fhrs_2_en-GB           2  east_counties       FHRS
# 302  fhrs_2_en-GB           2  east_counties       FHRS
# 308  fhrs_1_en-GB           1  east_counties       FHRS
# 402  fhrs_2_en-GB           2  east_counties       FHRS
# 422  fhrs_1_en-GB           1  east_counties       FHRS
# 438  fhrs_2_en-GB           2  east_counties       FHRS
# 444  fhrs_1_en-GB           1  east_counties       FHRS
# 458  fhrs_2_en-GB           2  east_counties       FHRS
# 470  fhrs_2_en-GB           2  east_counties       FHRS
# 478  fhrs_1_en-GB           1  east_counties       FHRS
# 493  fhrs_1_en-GB           1  east_counties       FHRS
# 530  fhrs_2_en-GB           2  east_counties       FHRS
# 551  fhrs_0_en-GB           0  east_counties       FHRS
# 552  fhrs_2_en-GB           2  east_counties       FHRS
# 583  fhrs_0_en-GB           0  east_counties       FHRS
# 585  fhrs_1_en-GB           1  east_counties       FHRS
# 587  fhrs_1_en-GB           1  east_counties       FHRS
# 612  fhrs_0_en-GB           0  east_counties       FHRS
# 616  fhrs_1_en-GB           1  east_counties       FHRS
# 643  fhrs_2_en-GB           2  east_counties       FHRS
# 654  fhrs_1_en-GB           1  east_counties       FHRS
# 656  fhrs_2_en-GB           2  east_counties       FHRS
# 699  fhrs_1_en-GB           1  east_counties       FHRS
# 729  fhrs_1_en-GB           1  east_counties       FHRS
# 739  fhrs_2_en-GB           2  east_counties       FHRS
# 766  fhrs_2_en-GB           2  east_counties       FHRS
# 821  fhrs_2_en-GB           2  east_counties       FHRS
# 890  fhrs_1_en-GB           1  east_counties       FHRS
# 931  fhrs_2_en-GB           2  east_counties       FHRS
# 932  fhrs_1_en-GB           1  east_counties       FHRS
# 938  fhrs_1_en-GB           1  east_counties       FHRS
# 956  fhrs_2_en-GB           2  east_counties       FHRS
# 968  fhrs_1_en-GB           1  east_counties       FHRS
# 986  fhrs_2_en-GB           2  east_counties       FHRS
#
#                                                 Scores Structural  \
# 17   {'Hygiene': 5, 'ConfidenceInManagement': 20, '...        5.0
# 47   {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 48   {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 113  {'Hygiene': 0, 'ConfidenceInManagement': 20, '...       10.0
# 120  {'Hygiene': 10, 'ConfidenceInManagement': 20, ...       10.0
# 151  {'Hygiene': 5, 'ConfidenceInManagement': 20, '...       10.0
# 163  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       15.0
# 171  {'Hygiene': 5, 'ConfidenceInManagement': 20, '...       10.0
# 184  {'Hygiene': 0, 'ConfidenceInManagement': 20, '...       10.0
# 250  {'Hygiene': 0, 'ConfidenceInManagement': 20, '...        0.0
# 254  {'Hygiene': 0, 'ConfidenceInManagement': 20, '...        0.0
# 264  {'Hygiene': 0, 'ConfidenceInManagement': 10, '...       15.0
# 282  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 299  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 302  {'Hygiene': 10, 'ConfidenceInManagement': 10, ...       15.0
# 308  {'Hygiene': 10, 'ConfidenceInManagement': 20, ...       20.0
# 402  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       15.0
# 422  {'Hygiene': 5, 'ConfidenceInManagement': 20, '...       10.0
# 438  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       15.0
# 444  {'Hygiene': 15, 'ConfidenceInManagement': 20, ...        0.0
# 458  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 470  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       15.0
# 478  {'Hygiene': 20, 'ConfidenceInManagement': 10, ...       15.0
# 493  {'Hygiene': 0, 'ConfidenceInManagement': 20, '...        5.0
# 530  {'Hygiene': 15, 'ConfidenceInManagement': 5, '...       10.0
# 551  {'Hygiene': 20, 'ConfidenceInManagement': 20, ...       15.0
# 552  {'Hygiene': 5, 'ConfidenceInManagement': 5, 'S...       15.0
# 583  {'Hygiene': 20, 'ConfidenceInManagement': 20, ...       15.0
# 585  {'Hygiene': 15, 'ConfidenceInManagement': 20, ...       15.0
# 587  {'Hygiene': 5, 'ConfidenceInManagement': 20, '...        5.0
# 612  {'Hygiene': 20, 'ConfidenceInManagement': 20, ...       15.0
# 616  {'Hygiene': 10, 'ConfidenceInManagement': 20, ...       20.0
# 643  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       15.0
# 654  {'Hygiene': 15, 'ConfidenceInManagement': 20, ...       10.0
# 656  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 699  {'Hygiene': 10, 'ConfidenceInManagement': 20, ...       10.0
# 729  {'Hygiene': 15, 'ConfidenceInManagement': 20, ...       15.0
# 739  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       15.0
# 766  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 821  {'Hygiene': 10, 'ConfidenceInManagement': 10, ...       15.0
# 890  {'Hygiene': 10, 'ConfidenceInManagement': 20, ...       10.0
# 931  {'Hygiene': 0, 'ConfidenceInManagement': 10, '...       15.0
# 932  {'Hygiene': 10, 'ConfidenceInManagement': 20, ...       15.0
# 938  {'Hygiene': 15, 'ConfidenceInManagement': 20, ...        5.0
# 956  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 968  {'Hygiene': 10, 'ConfidenceInManagement': 20, ...        5.0
# 986  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
#
#                           _id
# 17   59f8a8ffe7e4f80001d22e62
# 47   59f8a8ffe7e4f80001d22e81
# 48   59f8a8ffe7e4f80001d22e82
# 113  59f8a8ffe7e4f80001d22ec9
# 120  59f8a8ffe7e4f80001d22ed0
# 151  59f8a8ffe7e4f80001d22ef1
# 163  59f8a8ffe7e4f80001d22efd
# 171  59f8a8ffe7e4f80001d22f05
# 184  59f8a8ffe7e4f80001d22f12
# 250  59f8a8ffe7e4f80001d22f57
# 254  59f8a8ffe7e4f80001d22f5b
# 264  59f8a8ffe7e4f80001d22f66
# 282  59f8a8ffe7e4f80001d22f79
# 299  59f8a8ffe7e4f80001d22f8a
# 302  59f8a8ffe7e4f80001d22f8d
# 308  59f8a8ffe7e4f80001d22f93
# 402  59f8a8ffe7e4f80001d22ff4
# 422  59f8a8ffe7e4f80001d23009
# 438  59f8a8ffe7e4f80001d2301a
# 444  59f8a8ffe7e4f80001d23021
# 458  59f8a8ffe7e4f80001d23030
# 470  59f8a8ffe7e4f80001d2303c
# 478  59f8a8ffe7e4f80001d23044
# 493  59f8a8ffe7e4f80001d23053
# 530  59f8a8ffe7e4f80001d23078
# 551  59f8a8ffe7e4f80001d2308e
# 552  59f8a8ffe7e4f80001d2308f
# 583  59f8a8ffe7e4f80001d230b5
# 585  59f8a8ffe7e4f80001d230b7
# 587  59f8a8ffe7e4f80001d230ba
# 612  59f8a8ffe7e4f80001d230d4
# 616  59f8a8ffe7e4f80001d230d8
# 643  59f8a8ffe7e4f80001d230f4
# 654  59f8a8ffe7e4f80001d230ff
# 656  59f8a8ffe7e4f80001d23101
# 699  59f8a8ffe7e4f80001d2312f
# 729  59f8a8ffe7e4f80001d23150
# 739  59f8a8ffe7e4f80001d2315b
# 766  59f8a8ffe7e4f80001d23176
# 821  59f8a8ffe7e4f80001d231ae
# 890  59f8a8ffe7e4f80001d231f8
# 931  59f8a8ffe7e4f80001d23222
# 932  59f8a8ffe7e4f80001d23223
# 938  59f8a8ffe7e4f80001d23229
# 956  59f8a8ffe7e4f80001d2323b
# 968  59f8a8ffe7e4f80001d23247
# 986  59f8a8ffe7e4f80001d2325a
#
# [47 rows x 28 columns]

# %%
# We can also create a DataFrame which has only some columns
three_columns = first_1000[['RatingValue', 'FHRSID', 'PostCode']]

print('DataFrame with COLUMNS only:\n\n', three_columns.head())

# Or some rows
# Print the Dataframe with rows 950 to 960, could be any number of rows
print("\nDataFrame with a selection of ROWS:")
first_1000[950:960]
# Out:
# DataFrame with COLUMNS only:
#
#     RatingValue  FHRSID  PostCode
# 0            5  275908  NR35 1NT
# 1            5  275816  NR32 2LT
# 2            5  275292  NR33 0DX
# 3            5  568396  NR35 1AE
# 4            5  275965       NaN
#
# DataFrame with a selection of ROWS:
#                             AddressLine1      AddressLine2 AddressLine3  \
# 950                             The Byre       Hulver Road      Ellough
# 951                           Swan Hotel      Market Place    Southwold
# 952                             Swan Inn         Swan Lane       Barnby
# 953                      198 Church Road       Kessingland    Lowestoft
# 954                             Tally Ho  Watch House Hill   Mettingham
# 955  Beaches Coffee House And Restaurant     Kirkley Cliff    Lowestoft
# 956                         Haven Marina       School Road    Lowestoft
# 957                       4 Thoroughfare        Halesworth      Suffolk
# 958                       1 Market Place            Bungay      Suffolk
# 959                     Three Horseshoes    Lowestoft Road   North Cove
#
#     AddressLine4             BusinessName                       BusinessType  \
# 950      Beccles         The Suffolk Byre  Hotel/bed & breakfast/guest house
# 951      Suffolk           The Swan Hotel  Hotel/bed & breakfast/guest house
# 952      Beccles             The Swan Inn                  Pub/bar/nightclub
# 953      Suffolk        The Sweet Retreat            Restaurant/Cafe/Canteen
# 954       Bungay    The Tally Ho Tearooms            Restaurant/Cafe/Canteen
# 955      Suffolk  The Thatched Restaurant            Restaurant/Cafe/Canteen
# 956      Suffolk       The Third Crossing            Restaurant/Cafe/Canteen
# 957          NaN    The Thoroughfare Deli            Other catering premises
# 958          NaN          The Three Cooks            Restaurant/Cafe/Canteen
# 959      Beccles     The Three Horseshoes                  Pub/bar/nightclub
#
#     BusinessTypeID  ConfidenceInManagement  FHRSID  \
# 950           7842                     5.0  687339
# 951           7842                     5.0  275641
# 952           7843                     5.0  275663
# 953              1                     0.0  276040
# 954              1                     0.0  275752
# 955              1                     5.0  275848
# 956              1                    10.0  275904
# 957           7841                     5.0  723622
# 958              1                     0.0  705338
# 959           7843                     5.0  275758
#
#                                                Geocode  \
# 950  {'coordinates': [1.619514, 52.427507], 'type':...
# 951  {'coordinates': [1.679588, 52.326258], 'type':...
# 952  {'coordinates': [1.643437, 52.450652], 'type':...
# 953  {'coordinates': [1.724747, 52.414206], 'type':...
# 954  {'coordinates': [1.477451, 52.456995], 'type':...
# 955  {'coordinates': [1.743638, 52.46541], 'type': ...
# 956  {'coordinates': [1.720928, 52.472199], 'type':...
# 957  {'coordinates': [1.502513, 52.34369], 'type': ...
# 958  {'coordinates': [1.437435, 52.456457], 'type':...
# 959  {'coordinates': [1.625711, 52.447591], 'type':...
#
#                ...             NewRatingPending  PostCode  RatingDate  \
# 950            ...                        False  NR34 7XF  2014-06-27
# 951            ...                        False  IP18 6EG  2015-01-02
# 952            ...                        False  NR34 7QF  2016-03-01
# 953            ...                        False  NR33 7SF  2016-04-25
# 954            ...                        False  NR35 1TL  2015-09-15
# 955            ...                        False  NR33 0BY  2016-03-09
# 956            ...                        False  NR33 9NB  2016-03-05
# 957            ...                        False  IP19 8AH  2014-12-05
# 958            ...                        False  NR35 1EG  2014-09-24
# 959            ...                        False  NR34 7PH  2016-01-22
#
#         RatingKey RatingValue         Region SchemeType  \
# 950  fhrs_5_en-GB           5  east_counties       FHRS
# 951  fhrs_5_en-GB           5  east_counties       FHRS
# 952  fhrs_5_en-GB           5  east_counties       FHRS
# 953  fhrs_5_en-GB           5  east_counties       FHRS
# 954  fhrs_5_en-GB           5  east_counties       FHRS
# 955  fhrs_5_en-GB           5  east_counties       FHRS
# 956  fhrs_2_en-GB           2  east_counties       FHRS
# 957  fhrs_5_en-GB           5  east_counties       FHRS
# 958  fhrs_5_en-GB           5  east_counties       FHRS
# 959  fhrs_5_en-GB           5  east_counties       FHRS
#
#                                                 Scores Structural  \
# 950  {'Hygiene': 0, 'ConfidenceInManagement': 5, 'S...        0.0
# 951  {'Hygiene': 5, 'ConfidenceInManagement': 5, 'S...        5.0
# 952  {'Hygiene': 0, 'ConfidenceInManagement': 5, 'S...        5.0
# 953  {'Hygiene': 0, 'ConfidenceInManagement': 0, 'S...        5.0
# 954  {'Hygiene': 0, 'ConfidenceInManagement': 0, 'S...        0.0
# 955  {'Hygiene': 0, 'ConfidenceInManagement': 5, 'S...        5.0
# 956  {'Hygiene': 15, 'ConfidenceInManagement': 10, ...       10.0
# 957  {'Hygiene': 5, 'ConfidenceInManagement': 5, 'S...        5.0
# 958  {'Hygiene': 5, 'ConfidenceInManagement': 0, 'S...        5.0
# 959  {'Hygiene': 0, 'ConfidenceInManagement': 5, 'S...        5.0
#
#                           _id
# 950  59f8a8ffe7e4f80001d23235
# 951  59f8a8ffe7e4f80001d23236
# 952  59f8a8ffe7e4f80001d23237
# 953  59f8a8ffe7e4f80001d23238
# 954  59f8a8ffe7e4f80001d23239
# 955  59f8a8ffe7e4f80001d2323a
# 956  59f8a8ffe7e4f80001d2323b
# 957  59f8a8ffe7e4f80001d2323c
# 958  59f8a8ffe7e4f80001d2323d
# 959  59f8a8ffe7e4f80001d2323e
#
# [10 rows x 28 columns]

# %% [markdown]
# Using the existing `first_1000` DataFrame, try and create a dataset which outputs the columns FHRSID, PostCode, LocalAuthorityName, with any establishment where `RatingValue < 3`

# %%
# YOUR CODE HERE
three_columns = first_1000[['FHRSID', 'PostCode', 'LocalAuthorityName']][first_1000['RatingValue'] < 3]
print(three_columns.shape)

three_columns
# Out:
# (47, 3)
#      FHRSID  PostCode LocalAuthorityName
# 17   743308  NR32 2EN            Waveney
# 47   275470  NR34 9TL            Waveney
# 48   275565  NR35 1BG            Waveney
# 113  275772  IP18 6QG            Waveney
# 120  275152  NR32 2TD            Waveney
# 151  690379       NaN            Waveney
# 163  275438  NR33 9RW            Waveney
# 171  275136  NR33 0RY            Waveney
# 184  275247  NR32 1BA            Waveney
# 250  275405  NR32 4SF            Waveney
# 254  780961       NaN            Waveney
# 264  275375  NR32 2HA            Waveney
# 282  275996  NR32 1HZ            Waveney
# 299  842935  IP18 6DS            Waveney
# 302  275099  NR32 2AA            Waveney
# 308  275785  NR34 7JF            Waveney
# 402  275239  NR33 0BZ            Waveney
# 422  275214  NR32 1HR            Waveney
# 438  275567  NR35 1EZ            Waveney
# 444  275236  NR33 0DF            Waveney
# 458  275297  NR33 0AZ            Waveney
# 470  275368  NR32 2JU            Waveney
# 478  275746  NR33 7TF            Waveney
# 493  275340  NR32 2BW            Waveney
# 530  275734  NR33 7SJ            Waveney
# 551  275201  NR32 1XN            Waveney
# 552  275603  IP19 8AR            Waveney
# 583  275316  NR32 2NZ            Waveney
# 585  481032  IP18 6NS            Waveney
# 587  804010  NR32 1LR            Waveney
# 612  275336  NR33 7AU            Waveney
# 616  275858  NR35 1NZ            Waveney
# 643  275763  NR32 3BL            Waveney
# 654  275452  NR34 9TA            Waveney
# 656  275164  NR32 2EH            Waveney
# 699  275498  NR34 9DH            Waveney
# 729  275731  NR33 7SB            Waveney
# 739  716558  NR33 7NA            Waveney
# 766  275933  NR32 5DZ            Waveney
# 821  275135  NR33 0RY            Waveney
# 890  275556  NR35 1AX            Waveney
# 931  276048  NR32 1PA            Waveney
# 932  275112  NR33 9JU            Waveney
# 938  275202  NR32 1XN            Waveney
# 956  275904  NR33 9NB            Waveney
# 968  401859  NR32 1NT            Waveney
# 986  275169  NR33 0QG            Waveney

# %% [markdown]
# A `DataFrame` is an object in the `Pandas` library, but in addition we have the `Series` object, a collection of which makes up the `DataFrame`.
#
# Many of the operations we can perform on a `Series` can also be performed on a `DataFrame`.  It is a `Series` object which we will be using this week.
#
# It is possible to perform an operation on each element in the `Series`, as well as call functions which require all of these such as `mean()`.

# %%
print(first_1000['RatingValue'].head(), '\n')
print(first_1000['RatingValue'].head() * 100, '\n')
print(first_1000['RatingValue'].head() * 23 > 100)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: RatingValue, dtype: int64
#
# 0    500
# 1    500
# 2    500
# 3    500
# 4    500
# Name: RatingValue, dtype: int64
#
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: RatingValue, dtype: bool

# %% [markdown]
# As well as being a part of a `DataFrame`, it is possible to create a `Series` from a list type object, for example see the code below:

# %%
s = pd.Series([8,6,2,7,9,6])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    8
# 1    6
# 2    2
# 3    7
# 4    9
# 5    6
# dtype: int64

# %% [markdown]
# Create a `Series` object `rating_series` which contains the `RatingValue` column from the `first_1000 DataFrame` object.
#
# Then display descriptive statistics from that object (mean, median, mode etc).  You can see the full list of available functions in [the documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html)

# %%
# YOUR CODE HERE
rating_series = pd.Series(first_1000['RatingValue'])
print(rating_series.mean())
print(rating_series.median())
print(rating_series.mode())
# Out:
# 4.542
# 5.0
# 0    5
# dtype: int64

# %% [markdown]
# ## Bokeh Charts
# Bokeh uses Pandas data structures as the basis for its charts.  We will now place the data structure we just generated onto various types of charts.
#
# In Bokeh, there is a class **`Plot`** which is the basis for the visualisations we will consider in more detail next week.  A `Chart` is a subclass of `Plot`, which is designed to allow the generation of common charts with the minimum amount of code.
#
# At its simplest, these charts simply accept an object such as a `DataFrame` or `Series`, and will output a chart.  For example, a simple bar chart looks as follows:

# %%
# To display the chart in the notebook, we need to run this function, otherwise calling 'show' will not work
output_notebook()

# Create a simple bar chart with made up data
bar_chart = Bar(pd.Series([8,6,2,7,9,3]))

# Display the bar chart
show(bar_chart)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="80fe5ab9-3f60-480c-a595-d877be8fbb87">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4e1e5a51-c145-46ec-8020-7a020b499bfa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4e1e5a51-c145-46ec-8020-7a020b499bfa").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4e1e5a51-c145-46ec-8020-7a020b499bfa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4e1e5a51-c145-46ec-8020-7a020b499bfa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6fb0c38a-a2f8-4543-9d8c-1983088acb24":{"roots":{"references":[{"attributes":{"label":{"value":"1"},"renderers":[{"id":"4b47f217-1cb8-4782-a576-cf9370a0fd4d","type":"GlyphRenderer"}]},"id":"0a34490d-6c05-43c1-b871-99c6e9c703fe","type":"LegendItem"},{"attributes":{"dimension":1,"plot":{"id":"fc221ee4-bce9-40be-b60e-69024bfe1927","subtype":"Chart","type":"Plot"},"ticker":{"id":"d985a7b7-bd5e-4cbe-a700-45fa0a55d37a","type":"BasicTicker"}},"id":"5ace4d00-09fc-49dc-aa2e-826406987c04","type":"Grid"},{"attributes":{"plot":null,"text":null},"id":"6743b0fd-cf89-4fdf-82e2-c52d0560777c","type":"Title"},{"attributes":{"callback":null,"factors":["0","1","2","3","4","5"]},"id":"c9e32f83-27c3-4e9d-9d62-96da9c1dbe1b","type":"FactorRange"},{"attributes":{"data_source":{"id":"91fe2ff5-043a-4a44-a175-839b9f425c00","type":"ColumnDataSource"},"glyph":{"id":"84c2a75f-bc4b-46db-9c39-293e9e83624c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9c538da7-7241-4e5f-8c45-be6582f35b5a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5c4030fe-f730-4df5-8816-4a14142d965a","type":"ColumnDataSource"},"glyph":{"id":"35ef6d0b-c9b3-41ef-a704-04b1d18454a6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6afca389-e619-42c8-b6d4-cd8325086932","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b61e0b87-a624-4d8f-ac31-433398c8f1c2","type":"PanTool"},{"id":"cff91dfc-910a-46fe-ba8a-c4b90a16dedd","type":"WheelZoomTool"},{"id":"bb93f219-2138-4b76-8246-bfde5cb007b9","type":"BoxZoomTool"},{"id":"2c404e22-19da-4a69-a3e0-6de7a4b45b0b","type":"SaveTool"},{"id":"9ef284fd-03c4-4db9-8664-430e59529124","type":"ResetTool"},{"id":"d373d4a7-efac-401c-b461-ac09c1ccea84","type":"HelpTool"}]},"id":"97c8722b-17f4-4f52-8cfa-40b925fabc5b","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"84c2a75f-bc4b-46db-9c39-293e9e83624c","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_alpha","fill_alpha","line_color","y","x","height","color","label","width"],"data":{"chart_index":[{"index":5}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"index":[5],"label":[{"index":5}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["5"],"y":[1.5]}},"id":"44364458-bbb4-4384-8f50-ddba995e3bdf","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"d05b1bc8-8994-4e96-9268-3ca9ed04c589","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"dea47c70-931f-4376-acc1-5a760cf06d2f","type":"LinearAxis"}],"renderers":[{"id":"d8e11fc6-08ce-4c81-8006-307c387a845a","type":"BoxAnnotation"},{"id":"6afca389-e619-42c8-b6d4-cd8325086932","type":"GlyphRenderer"},{"id":"4b47f217-1cb8-4782-a576-cf9370a0fd4d","type":"GlyphRenderer"},{"id":"9c538da7-7241-4e5f-8c45-be6582f35b5a","type":"GlyphRenderer"},{"id":"9322fdd4-9567-4f0f-9fe1-2f55ec265eb3","type":"GlyphRenderer"},{"id":"bbb4d609-c45e-4261-9b80-36ec0cf35984","type":"GlyphRenderer"},{"id":"09d5e93f-5d59-4ed5-95b7-8caa8bf2c7ba","type":"GlyphRenderer"},{"id":"201e066c-01c5-4781-b77c-7a17cdccd45a","type":"Legend"},{"id":"d05b1bc8-8994-4e96-9268-3ca9ed04c589","type":"CategoricalAxis"},{"id":"dea47c70-931f-4376-acc1-5a760cf06d2f","type":"LinearAxis"},{"id":"5ace4d00-09fc-49dc-aa2e-826406987c04","type":"Grid"}],"title":{"id":"6743b0fd-cf89-4fdf-82e2-c52d0560777c","type":"Title"},"tool_events":{"id":"b23338da-ff3f-42bc-888c-38c579b4b41b","type":"ToolEvents"},"toolbar":{"id":"97c8722b-17f4-4f52-8cfa-40b925fabc5b","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"c9e32f83-27c3-4e9d-9d62-96da9c1dbe1b","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"9af2f1d0-8897-4109-96be-814350d20d93","type":"Range1d"}},"id":"fc221ee4-bce ...

# %% [markdown]
# There are other charts which you can use such as a Histogram, Line graph, and scatter plot.  View the Bokeh **[user guide for charts](http://bokeh.pydata.org/en/latest/docs/reference/charts.html)** to see the options available to customise the chart created above.  In addition it is possible to customise the display.

# %% [markdown]
# # Randomness
#
# A feature which NumPy supports is that of generating random numbers.  This is important, for example, in generating a random sample from a population.  The randomness, however, is not _truly_ random, but rather pseudo-random, i.e., it will generate predictable values based on the initial **_seed_** that it accepts.
#
# This feature means that if we know the seed, we can reproduce the results we wish to share provided that we have the same data, which is a desirable property. Though this may sound counter-intuitive it allows others to run our code using the same seed and they will get the same output, the code can then be run using a different seed value.
#
# Consider the scenario where you want to populate an array with random data, you can use the `numpy.random.randint` function as below:

# %%
# import numpy.random
import numpy as np
# The numbers generated will include the low value
low = 0
# The numbers generated will not include the high value, but will go up to high - 1
high = 10
#np.random.randint(low, high, size=10)

print(np.random.randint(low, high, size=12))
# Out:
# [3 2 9 7 4 0 1 7 3 8 8 0]

# %% [markdown]
# Create a loop with 10 iterations, where each iteration prints a randomly generated array of size 10.  Notice how each array has set of different values.

# %%
# YOUR CODE HERE
print('code test 1')
ri = 0
while (ri < 10):
    print(np.random.randint(0, 50, size=10))
    ri = ri + 1

#or
print('code test 2')
for ri in range(0, 10):
    print(np.random.randint(0, 50, size=10))
# Out:
# code test 1
# [20 10 31 34 40 40 17  0  1  0]
# [13  3  7 46 15 13 32  9 48 24]
# [20 48 36  1  2 49 34  9 18 42]
# [ 7 39 20 42  3 34  5 22 46 40]
# [35 14 35 17 35 26  6 33 25 40]
# [16  3 35 10  1 30 10 35  3 33]
# [16 16  5 21 37 47  3 28 21 48]
# [44 10  9  6 19 32 29  5 31 16]
# [49 41 15 29 44 45 23 43 13 28]
# [42  8  5 27 19 13 16 33 17 17]
# code test 2
# [39  0 30  3  4 14 47 32 31 17]
# [ 3  5 37 15 17 23  6 49 20  2]
# [32  6 12 31 32 47 39  0  7  4]
# [10 25 47 24 44 29 42 26 44 20]
# [44 18  0  8 12  9 49 25 24 40]
# [10 26  3 25 49 47 22 45 34  1]
# [35 34  5 37 10 35 32  5 33 12]
# [19 31 16 33 25 25  4  0  8 21]
# [10 15  4 36  1 28 41 21 40 14]
# [17  0  8 49 48 24 42 47 45 33]

# %% [markdown]
# For many situations, this is desirable.  However, where we want to be able to reproduce, e.g., sample sizes, we want our samples to be reproducible.  To do this, we use the `RandomState` class in NumPy, where we specify our seed, as follows:

# %%
# Run this cell several times - observe the outcome
rs = np.random.RandomState(543210)
j = rs.randint(low, high, size=10)
print(j)
# Out:
# [8 4 1 0 7 6 4 6 8 3]

# %% [markdown]
# In the cell below, generate the same loop as before, except this time instantiate the `RandomState` object to a value of 123456:

# %%
# YOUR CODE HERE
rs = np.random.RandomState(123456) #seed value = 123456
j = rs.randint(low, high, size=10)
print(j)
# Out:
# [1 2 1 8 0 7 4 8 4 2]

# %% [markdown]
# ## IQR and Outliers
#
# In the videos, Sergej talked about "outliers" in a dataset.  In this worksheet, we'll give a slightly more detailed definition about what exactly they are, and the effect they can have on data.
#
# An outlier is a value which is atypical of the rest of the dataset.  For example, consider this set of data from [searches on the UK income tax calculator](https://www.incometaxcalculator.org.uk/average-salary-uk.php).  If we draw a distribution of them, we will notice a big difference in the values:

# %%
import pandas as pd
import numpy as np
from bokeh.charts import Histogram, output_notebook, show
from bokeh.models import Axis

salaries_list =  [30000,18000,25000,20000,40000,50000,35000,45000,22000,60000,24000,28000,23000,
             16000,100000,21000,26000,15000,32000,19000,17000,70000,27000,55000,18500,80000,
             36000,65000,42000,38000,12000,2481300,75000,33000,19500,43000,48000,120000,14000,
             17500,90000,34000,29000,16500,11000,31000,150000,37000,13000,22500,52000,10000,85000,
             44000,200000,39000,46000,110000,27500,21500,47000,23500,15500,41000,26500,15600,16800,
             20500,14500,130000,250000,24500,28500,72000,140000,32500,8000,53000,95000,25500]


salaries = pd.DataFrame({'Salaries': salaries_list})
print(salaries.head(6))

from bokeh.plotting import figure, show, output_file
output_notebook()
hist = Histogram(salaries, bins=50)
# Show absolute number on axis rather than E notation:
xaxis = hist.select(dict(type=Axis))[0]
xaxis.formatter.use_scientific = False
show(hist)
# Out:
#    Salaries
# 0     30000
# 1     18000
# 2     25000
# 3     20000
# 4     40000
# 5     50000
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c4b3e534-b5a2-4521-95a5-65eea9cca454">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fe69e6f0-e481-4fbb-a5c9-e6c8eebdcf9d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fe69e6f0-e481-4fbb-a5c9-e6c8eebdcf9d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fe69e6f0-e481-4fbb-a5c9-e6c8eebdcf9d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fe69e6f0-e481-4fbb-a5c9-e6c8eebdcf9d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ecbcf0d6-aea7-4011-a449-0464b14d1888":{"roots":{"references":[{"attributes":{"data_source":{"id":"6a179954-6bf0-417e-969a-b9cc8c699eac","type":"ColumnDataSource"},"glyph":{"id":"fda63462-0084-4dad-a846-a5ab50cd2adf","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0f7c0008-72fb-4fb7-ac0a-e162c61ab33c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","fill_alpha","line_color","y","x","height","color","label","width"],"data":{"chart_index":["(848922.000000, 898388.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(848922.000000, 898388.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[49466.0],"x":["873655.0"],"y":[0.0]}},"id":"5560b678-acc2-4445-b272-aca1512de887","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0bd9e3d1-46af-46e0-8903-b96b140088e9","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd6c761b-66d8-4708-bc0d-96486e1896e6","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_alpha","fill_alpha","line_color","y","x","height","color","label","width"],"data":{"chart_index":["(502660.000000, 552126.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(502660.000000, 552126.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[49466.0],"x":["527393.0"],"y":[0.0]}},"id":"46976607-32b7-4e1e-b76c-5c551e9a26af","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ca7ef881-c1f4-4325-ae14-4db2f3420674","type":"ColumnDataSource"},"glyph":{"id":"5c8bd789-cc8a-4900-891d-471374bfdbdd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d8955929-c9af-4584-983a-a31adad31e8f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","fill_alpha","line_color","y","x","height","color","label","width"],"data":{"chart_index":["(2431834.000000, 2481300.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(2431834.000000, 2481300.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[49466.0],"x":["2456567.0"],"y":[0.5]}},"id":"70e5510d-d0e7-4bef-a40f-4587bb0bab0b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9d936059-3808-4a67-938f-4b272bc03508","type":"Rect"},{"attributes":{"data_source":{"id":"9d5751cd-3960-46f2-8064-e374bce5d37f","type":"ColumnDataSource"},"glyph":{"id":"dbe4abb0-64da-4297-bff2-5ce9ee429df2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"292828d4-b79f-40c8-99fb-b2f771d2bf83","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5560b678-acc2-4445-b272-aca1512de887","type":"ColumnDataSource"},"glyph":{"id":"1497132a-92f0-4fc2-a706-d79f51a6729a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"dc5818b8-4623-4196-adea-c82dad1d7f67","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c324814-a566-4c8e-8871-ecd538c6fe0b","type":"Rect"},{"attributes":{"plot":{"id":"ce70b5fc-4c25-4d21-935b-5288f8c6c1c1","subtype":"Chart","type":"Plot"}},"id":"6f1a1a7c-46ce-47a0-8373-6ff5af65241d","type":"ResetToo ...

# %% [markdown]
# You will notice, the massive outlier on the right, where the person in question earns nearly £2.5 million.  It makes it very difficult to get the chart to display anything useful, and has a significant effect on our data. For example, see the code below which shows the difference in number between the mean and the median:

# %%
print('The mean is: %f, and the median is %f' % (salaries.mean(), salaries.median()))
# Out:
# The mean is: 76371.250000, and the median is 31500.000000

# %% [markdown]
# Task: Remove the highest value from the dataset and see how this changes the mean and the median.
#
# Further information about explicit location based indexing .loc can be found on this [Pandas Documentation](http://pandas.pydata.org/pandas-docs/version/0.15.0/indexing.html) page.

# %%
# YOUR CODE HERE
salaries = salaries[salaries['Salaries'] < 2000000]

print('The mean is: %f, and the median is %f' % (salaries.mean(), salaries.median()))
# Out:
# The mean is: 45929.113924, and the median is 31000.000000

# %%
#alternate code using loc for indexing by label
salaries = salaries.loc[salaries['Salaries'] < 2000000]

print('The mean is: %f, and the median is %f' % (salaries.mean(), salaries.median()))
# Out:
# The mean is: 45929.113924, and the median is 31000.000000

# %% [markdown]
# Moving the top value had a considerable effect on the mean value of the dataset, decreasing it by over £30,000, however the result is still quite a bit higher than the median.  So although the £2.5 million figure is obviously an outlier, how can we define an outlier more concretely?  To start, we will consider the interquartile range (IQR):
#
# ## IQR
#
# The IQR is calculated as follows:
#
# 1. Ordering the data by value
#
# 2. Taking the middle value from the _bottom_ half of the data (lower quartile, known as Q1)
#
# 3. The median is known as Q2
#
# 3. Taking the middle value from the _top_ half of the data (upper quartile, known as Q3)
#
# 4. The IQR is then calculated with Q3 - Q1
#
# The Q1 and Q2 values are considered as the 25th and 75th percentiles, since they represent the values 25% and 75% through the ordered data.  Luckily, there are functions within Pandas which allow the calculation of these percentiles, which provide us with the IQR: the [`quantile`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.quantile.html) function on a `DataFrame` which takes a float between 0 and 1 to get the appropriate percentile.  For example, the median could be calculated as follows:

# %%
salaries.quantile(0.5)
# Out:
# Salaries    31000.0
# Name: 0.5, dtype: float64

# %% [markdown]
# Task: Calculate the IQR of the salaries data using Pandas.  Print out the value of the upper and lower quartiles so you can check the answer is correct

# %%
# YOUR CODE HERE
upper = salaries.quantile(0.75)
lower = salaries.quantile(0.25)
iqr = upper - lower
print('upper quartile = %f\nlower quartile = %f\nIQR = %f'%(upper, lower, iqr))
# Out:
# upper quartile = 51000.000000
# lower quartile = 20250.000000
# IQR = 30750.000000

# %% [markdown]
# ## Outliers
#
# Having introduced the IQR, we can now consider what constitues an outlier.  As a rule of thumb, an outlier can be defined as follows:
#
# - `lower_quartile - (1.5 * IQR)`
# - `upper_quartile + (1.5 * IQR)`
#
# This is highly dependent on the data, and may not be appropriate for all situations, as is the decision of what to do with them.  For the time being, we will simply exclude data which are outside these limits.
#
# To do this, consider the following Pandas code, which excludes outliers from the salaries data.  It uses a more complicated version of `.loc`, where it filters on two conditions

# %%
# You don't need to write anything here
# Create the dataset again, rather than use the one with the top value taken out
salaries = pd.DataFrame({'Salaries': salaries_list})
upper = float(salaries.quantile(0.75))
lower = float(salaries.quantile(0.25))
#ValueError: Can only compare identically-labeled Series objects solution was to ADD FLOAT!!!
iqr = upper - lower

salaries = salaries['Salaries'][(salaries['Salaries'] > (float(lower) - (iqr * 1.5)))
                     & (salaries['Salaries'] < (float(upper) + (iqr * 1.5)))]

# salaries = salaries['Salaries'] < lower
# salaries = salaries.loc[salaries['Salaries'] <= lower]
print('The mean is: %f, and the median is %f' % (salaries.mean(), salaries.median()))
# Out:
# The mean is: 35116.666667, and the median is 28250.000000

# %% [markdown]
# The purpose of this exercise was to introduce the concept of an outlier, and how much of an effect it can have on data, and to give some practice using Pandas.  There are many different ways that outliers could be defined, and circumstances where they could or should not be excluded.
