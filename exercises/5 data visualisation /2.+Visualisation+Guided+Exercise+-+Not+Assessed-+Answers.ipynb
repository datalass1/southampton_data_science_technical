# %% [markdown]
# # Data Visualisation With Bokeh
#
# Last week we looked at how statistics could inform our understanding of data.  In this week, we look at how data can be visualised, in particular using the **[Bokeh](http://bokeh.pydata.org/en/latest/)** library.
#
# We used some of the basic **[`Chart`](http://bokeh.pydata.org/en/latest/docs/reference/charts.html)** functions last week to visualise distributions.  This week will focus on geographical data and how this can be represented on a map.

# %%
# You don't need to write anything here
# Add the initial imports
import pandas as pd
from bokeh.plotting import Figure
from bokeh.io import show, output_notebook, push_notebook
from bokeh.models import *
#from bokeh.plotting import figure
from bokeh.tile_providers import WMTSTileSource
from ipywidgets import *
import ipywidgets as widgets


import numpy as np
output_notebook()

# We will need this function to calculate a position on the map when given lattitude and longitude data
def wgs84_to_web_mercator(df, lon="lon", lat="lat"):
    """
    Converts decimal longitude/latitude to Web Mercator format
    Source https://github.com/bokeh/bokeh-notebooks/blob/master/tutorial/11%20-%20geo.ipynb
    """
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="27496bb0-b7f6-42c0-9120-43aabce93ada">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Widgets
#
# Widgets are functions which convert **Python** code to **HTML** code for output in the notebook.  Bokeh has its own widgets, but for this exercise we will focus on the widgets used within the Jupyter Notebook:**[`ipywidgets`](http://ipywidgets.readthedocs.io/en/latest/index.html)**.  These widgets could range from a simple text description to interactive widgets which may modify the appearance of Bokeh visualisations in real time.
#
# We will start with a **['slider'](http://bokeh.pydata.org/en/latest/docs/gallery/slider.html)** widget, which we will use to modify a simple line graph.  We will use the **[`interact`](http://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html)** function to do this.  It works by passing a function name as a parameter, and every time that the slider is moved, it calls the function.  We demonstrate this in the following cell:

# %%
# You don't need to write anything here

# This function is called every time we change the value on the slider
# Notice that we are calling the function 'interact' which creates an interactive widget
# 'interact' is a function called from ipywidgets
def f(x):
    print("Move the slider!", x)
    return x
# x=2 means that the first time it calls the function, the `x` parameter of `f` will have a value 2
interact(f, x=5)
# Out:
# Move the slider! 5
# 5
# <function __main__.f>

# %%
interact(f, x='hello')
# Out:
# Move the slider! hello
# 'hello'
# <function __main__.f>

# %% [markdown]
# In the next cell, we introduce the **[`Figure` class](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.figure.Figure)** to create our line graph.  We briefly demonstrated this in **week 3** when demonstrating the Iris dataset for linear regression.  For this week, we will go into a bit more about it, since we will be using it in our visualisation in the assignment.
#
# We use the **[`line` method](http://bokeh.pydata.org/en/0.10.0/docs/reference/plotting.html#bokeh.plotting.Figure.line)** to add our line to the graph.  On this occasion, we are presenting a simple graph of $y = x^2$, and use the **`show`** function to display the graph.  Notice that we pass it **[`notebook_handle=true`](http://bokeh.pydata.org/en/latest/docs/user_guide/notebook.html#working-in-the-notebook)**.  This gives other methods a means of dynamically updating it later.

# %%
# You don't need to write anything here
# Here we create an empty figure to which we add a line representing y=x**2

fig = Figure() 
li = fig.line(x=pd.Series([1,2,3,4,5,6,7]), y=pd.Series([1,4,9,16,25,36,49]))

show(fig, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="541618f3-589c-4a40-ba0d-5a3594521d98"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("541618f3-589c-4a40-ba0d-5a3594521d98").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("3456e0fb-ec9f-49f8-af84-2605e99609a2", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById
type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"626c0865-a374-4cad-a91f-6cbea827ec36","type":"ColumnDataSource"},"glyph":{"id":"922b64e1-413b-430b-a0e7-c8c579474bef","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c3d1abec-5e1d-41cb-9854-b8232a7975ef","type":"Line"},"selection_glyph":null},"id":"a1275715-20e4-45b2-b528-3db797b2e8c3","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f95624c6-93dd-40d2-a99e-8e227aee8217","type":"PanTool"},{"id":"640efd22-7bb3-48bc-a21a-cff6f6915252","type":"WheelZoomTool"},{"id":"117b8fc3-99ac-47f1-b481-dd8fbf7e5a7d","type":"BoxZoomTool"},{"id":"d1240133-6779-42f4-bb3c-b29230806c3b","type":"SaveTool"},{"id":"ef0acadf-e2c3-4650-ac98-b3aeeea73aa6","type":"ResetTool"},{"id":"39bc242e-2a9a-4991-a09f-60bce9f0073a","type":"HelpTool"}]},"id":"3a14a464-8661-471b-b759-56fa8f683967","type":"Toolbar"},{"attributes":{"formatter":{"id":"c23190a2-76f9-4428-8b5e-38dff7a69752","type":"BasicTickFormatter"},"plot":{"id":"9859ed60-b624-4d62-8e05-338f39a26f9e","subtype":"Figure","type":"Plot"},"ticker":{"id":"8a5a46e7-6cc6-4082-821c-7991ac89d79e","type":"BasicTicker"}},"id":"82b6f4e2-b9b4-46d0-bd43-7a7b1d3a0b17","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c3d1abec-5e1d-41cb-9854-b8232a7975ef","type":"Line"},{"attributes":{"callback":null},"id":"ef2ef ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %% [markdown]
# If we want to **update** the figure, we can make use of the **[`handle`](http://bokeh.pydata.org/en/latest/docs/user_guide/notebook.html#notebook-handles)** we passed to the **`Figure`**.  Bokeh has a function for this called **[`push_notebook`](http://bokeh.pydata.org/en/latest/docs/reference/io.html)**, which will ***push*** any changes made to the notebook since the last time it was called.
#
# To update the data, we are going to update the data source of the line, by changing the values of the $y$ axis, so we have an equation of $y = x^3$.
#
# So, if we call as follows, it will update the figure above:

# %%
# You don't need to write anything here
# Now, we can adjust the value in the line figure above, and see the data change
li.data_source.data['y'] = li.data_source.data['x'] **3
push_notebook()

# %% [markdown]
# That shows the two elements required to make an interactive visualisation.  Now, try and put it all together:
#
# - Create a slider using `interact`, which calls function `g(x)`
# - `g(x)` should update the line of a plot to be x to the power `g(x)`
# - If you can make a slider work with integers, try and update using a [`FloatSlider`](http://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html) which increases in value 0.1 for every change instead of an `IntSlider` as in the example above.

# %%
# YOUR CODE HERE
# Place your figure code in this cell
fig = Figure()
li = fig.line(x=pd.Series([1,2,3,4,5,6,7]), y=pd.Series([1,4,9,16,25,36,49]))
show(fig, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f6248133-7cab-4293-afa0-a655a158e124"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f6248133-7cab-4293-afa0-a655a158e124").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("53495bc9-aa8e-424a-9e35-8c7a426ce0d6", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f6248133-7cab-4293-afa0-a655a158e124");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f6248133-7cab-4293-afa0-a655a158e124' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6e9edd79-e7da-49df-8c69-6bbed9898a39":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":
type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"91fe4b47-5d8a-4dde-a008-e47db6a8af1a","type":"Line"},{"attributes":{"overlay":{"id":"c61a27a4-ba9f-4ff5-af50-0027625f1f1c","type":"BoxAnnotation"},"plot":{"id":"e689d604-3889-4ce7-b928-c260b222a08e","subtype":"Figure","type":"Plot"}},"id":"5aba742c-1b39-4c88-8889-ef3d4265ecb0","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e039cce-9183-43ef-be38-68c1370041e0","type":"Line"},{"attributes":{"formatter":{"id":"f74b0010-79ee-45be-b3fc-f3407ffb2e36","type":"BasicTickFormatter"},"plot":{"id":"e689d604-3889-4ce7-b928-c260b222a08e","subtype":"Figure","type":"Plot"},"ticker":{"id":"91292589-b2e4-4a0d-81a2-2149da63500f","type":"BasicTicker"}},"id":"a831bde1-8577-4e87-b34c-913fb6e72433","type":"LinearAxis"},{"attributes":{"callback":null},"id":"2e0bed6b-f9e8-4221-969b-8effb9a9d2d2","type":"DataRange1d"},{"attributes":{"plot":{"id":"e689d604-3889-4ce7-b928-c2 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %%
# YOUR CODE HERE
# Place your slider code in this cell
def g(x):
    li.data_source.data['y'] = li.data_source.data['x'] **x
    push_notebook()
interact(g, x=3)
# Out:
# <function __main__.g>

# %% [markdown]
# ## Tools
#
# Notice on the side of the `Figure` object, there are a series of buttons.  These allow interactive exploration of the figure.  By default, Bokeh adds some to our figure, but we can add them ourselves in two ways.
#
# Firstly, we can use the **[`add_tool`](http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html#specifying-tools)** function for each tool manually.  For example, we might want to add the **`LassoSelectTool`**, we could simply pass an instance of this class to the **`add_tool`** function as follows:

# %%
# fig = Figure()
fig.add_tools(LassoSelectTool())
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b518da3a-d6c1-499d-8123-94ca63724f4c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b518da3a-d6c1-499d-8123-94ca63724f4c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b518da3a-d6c1-499d-8123-94ca63724f4c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b518da3a-d6c1-499d-8123-94ca63724f4c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6f0c851f-e29b-4d38-817b-d5ef5fa2caaf":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"80e8135d-3ca2-49d2-bc6e-3225474e81dd","type":"PanTool"},{"id":"066ac221-134c-4e00-9257-c946b150164b","type":"WheelZoomTool"},{"id":"5aba742c-1b39-4c88-8889-ef3d4265ecb0","type":"BoxZoomTool"},{"id":"1db49a5f-6fc4-458d-a764-d82fa0af8eb6","type":"SaveTool"},{"id":"0fa9fee3-a38e-4490-b1c7-f5007064e5c6","type":"ResetTool"},{"id":"c688ede1-528f-461e-8f41-5faed4ccefbb","type":"HelpTool"},{"id":"79f1ae70-d848-4f06-a134-8c3be72011d5","type":"LassoSelectTool"}]},"id":"80027ef7-18c0-4c8f-a2ba-dbbd9f8480dc","type":"Toolbar"},{"attributes":{"callback":null},"id":"175dfb72-088c-474f-90de-274fb63ac999","type":"DataRange1d"},{"attributes":{"data_source":{"id":"b4f4cdfd-a8dd-44c5-a4df-d8762f9c5b80","type":"ColumnDataSource"},"glyph":{"id":"91fe4b47-5d8a-4dde-a008-e47db6a8af1a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"6e039cce-9183-43ef-be38-68c1370041e0","type":"Line"},"selection_glyph":null},"id":"b6df7d79-9053-47da-9cb5-2dfda42de622","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"
type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e039cce-9183-43ef-be38-68c1370041e0","type":"Line"},{"attributes":{"formatter":{"id":"f74b0010-79ee-45be-b3fc-f3407ffb2e36"," ...

# %% [markdown]
# The **easier way** of doing this is to pass to the tools parameter when the `Figure` is created, which can be done in one of two ways:
# - By passing a list of `Tool` instances
# - A comma separated string of different tools
#
# See the two examples of code doing the same thing on empty `Figure` instances as follows:

# %%
tools_fig_1 = Figure(tools=[WheelZoomTool(), BoxSelectTool()], height=100)
show(tools_fig_1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4be213b3-be2b-4ef9-98cf-870b5a8313cc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4be213b3-be2b-4ef9-98cf-870b5a8313cc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4be213b3-be2b-4ef9-98cf-870b5a8313cc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4be213b3-be2b-4ef9-98cf-870b5a8313cc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"14d1aa86-9101-4c59-9f71-7388102ef7f9":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"27d9eb55-268d-491e-8d3d-c36fac28c94a","subtype":"Figure","type":"Plot"},"ticker":{"id":"c035f9ca-f6cf-43ed-b5a2-4a6215f1a609","type":"BasicTicker"}},"id":"1b2d7534-d68d-416d-b612-e139833ceb4a","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"55f09e8c-0a7c-4a37-98ed-7cc42d8f910b","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"27d9eb55-268d-491e-8d3d-c36fac28c94a","subtype":"Figure","type":"Plot"}},"id":"60e7348d-fcbd-4ac7-ac02-9adf3d2ed998","type":"WheelZoomTool"},{"attributes":{},"id":"714b7ce7-82b2-48b0-a166-eb5271ff3c3e","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"0616f121-1c3f-4de1-8a38-637e5d4ed549","type":"DataRange1d"},{"attributes":{},"id":"c035f9ca-f6cf-43ed-b5a2-4a6215f1a609","type":"BasicTicker"},{"attributes":{"below":[{"id":"f7a91a8d-f81f-478e-a16f-ec817645edfb","type":"LinearAxis"}],"height":100,"left":[{"id":"06977bb1-0556-408f-afea-819b15409fdc","type":"LinearAxis"}],"renderers":[{"id":"f7a91a8d-f81f-478e-a16f-ec817645edfb","type":"LinearAxis"},{"id":"326ad8b7-a40f-4c5e-9470-f1ce150ee577","type":"Grid"},{"id":"06977bb1-0556-408f-afea-819b15409fdc","type":"LinearAxis"},{"id":"1b2d7534-d68d-416d-b612-e139833ceb4a","type":"Grid"},{"id":"55f09e8c-0a7c-4a37-98ed-7cc42d8f910b","type":"BoxAnnotation"}],"title":{"id":"2586eb4f-24db-43b0-a703-268136721d32","type":"Title"},"tool_events":{"id":"bd609c94-d22e-4a00-901b-a7e84c28d808","type":"ToolEvents"},"toolbar":{"id":"c308c642-c949-4132-9771-afcca4a58925","type":"Toolbar"},"x_range":{"id":"0616f121-1c3f-4de1-8a38-637e5d4ed549","type":"DataRange1d"},"y_range":{"id":"0b91ceec-f1d6-405f-ae2b-01974d2f99e9","type":"DataRange1d"}},"id":"27d9eb55-268d-491e-8d3d-c36fac28c94a","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"ca6ab331-e60a-4627-a7b7-0a76315cf8b6","type":"BasicTicker"},{"attributes":{},"id":"bd609c94-d22e-4a00-901b-a7e84c28d808","type":"ToolEvents"},{"attributes":{"formatter":{"id":"567669cf-c5af-43d5-810a-907502eed7da","type":"BasicTickFormatter"},"plot":{"id":"27d9eb55-268d-491e-8d3d-c36fac28c94a","subtype":"Figure","type":"Plot"},"ticker":{"id":"c035f9ca-f6cf-43ed-b5a2-4a6215f1a609
}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function r

# %% [markdown]
# The full list of **[available tools](http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html#specifying-tools)** and their usage can be seen in the **[Bokeh tools user guide](http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html)**.  If you don't remember the name of the tool you want and enter the wrong value, Bokeh will warn you and give you some suggestions for tools you might like to add.

# %% [markdown]
# # Data Sources
# This (updating the graph/data) was possible, because when we created the line to display on our graph, we gave it the variable `li`, and we were still able to access the `li` variable.  This was a [`Glyph`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#plotting-with-basic-glyphs), which has associated with it a [`ColumnDataSource`](http://bokeh.pydata.org/en/latest/docs/reference/models/sources.html#bokeh.models.sources.ColumnDataSource) type created from the values inserted.
#
# We have already seen a Pandas `DataFrame`, which is a generic data structure for holding data.  The `ColumnDataSource` is part of `Bokeh` rather than `Pandas`, and is used specifically as a means of storing data for a graph.
#
# This object can be accessed as the `data_source` of the `Glyph`, and the `data` attribute is a series of key/value pairs derived from the source data.

# %% [markdown]
# ##### You don't need to write anything here
# # Show the variables associated with the data source of the `ColumnDataSource`
# print(vars(li.data_source))
#
# # Show a column of the source data
# print('\n`y` data from the graph:\n', li.data_source.data['y'])

# %% [markdown]
# Having introduced the concept of widgets, figures, and the ColumnDataSource, we are now going to make use of the **[Bokeh map tiling](http://geo.holoviews.org/Working_with_Bokeh.html)** feature.  We will use sample data from Bokeh, based on states in the USA, and we will match each of these states to the winner in the US presidential election of 2016.
#
# We will create a map of the USA, which will add the correct colour to an individual state when we select from a checkbox.
#
# To begin, we will import the data, and add colour for a single state (California):

# %%
# You don't need to write anything here
# Here we import our data and make a copy
# These data includes the co-ordinates of the US state borders
from bokeh.sampledata.us_states import data
us_states = data
# These data is the winners from the 2016 election by state
election_winners = pd.read_csv('election.csv')
us_states['TX']['name']
# Out:
# 'Texas'

# %%
# You don't need to write anything here
# Here we are preparing a map as a `Tile` which we will use as a background on the figure
from bokeh.plotting import figure
from bokeh.tile_providers import WMTSTileSource

# Create a figure which has co-ordinates centred on the USA
x_range,y_range = ((-13884029,-7453304), (2698291,6455972))

# Create the figure
fig = figure(tools='pan, wheel_zoom', x_range=x_range, y_range=y_range)
fig.axis.visible = False

# %%
# You don't need to write anything here
# In this cell we add a map tile to the figure, adding a URL in a standard format to specify the map details 
url = 'http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png'
attribution = "Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL"
fig.add_tile(WMTSTileSource(url=url, attribution=attribution))
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="134b8ce5-f118-4129-b3d9-f068cf0ea0e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("134b8ce5-f118-4129-b3d9-f068cf0ea0e6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("134b8ce5-f118-4129-b3d9-f068cf0ea0e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '134b8ce5-f118-4129-b3d9-f068cf0ea0e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8772fe3a-6811-43dd-9ac4-f390be3f20e3":{"roots":{"references":[{"attributes":{"plot":{"id":"65e31c6f-e8e5-4aee-b4d6-ac1217af4279","subtype":"Figure","type":"Plot"},"ticker":{"id":"fbcd07a1-4053-4f8c-94e9-85fd1305c1a7","type":"BasicTicker"}},"id":"5515187c-0e34-45ce-a147-e444435be865","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"
subtype":"Figure","type":"Plot"},"ticker":{"id":"2b48b1ee-cc49-42b0-a58b-e524d1a93b20","type":"BasicTicker"},"visible":false},"id":"cf1a28b9-e682-4efc-bf48-06df78405fc0","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"65e31c6f-e8e5-4aee-b4d6-ac1217af4279","subtype":"Figure","type":"Plot"},"ticker":{"id":"2b48b1ee-cc49-42b0-a58b-e524d1a93b20","type":"BasicTicker"}},"id":"f8b8b112-def4-43e7-91a5-966b7b288d15","type":"Grid"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"b7c36158-08c2-4710-8ac7-eb650d1744b1","type":"WMTSTileSource"},{"attributes":{"callback":null,"end":-7453304,"start":-13884029},"id":"8e387ab6-cc3d-4864-bc7b-d0e5113b5c2e","type":"Range1d"},{"attributes":{},"id":"fbcd07a1-4053-4f8c-94e9-85fd1305c1a7","type": ...
#             var render_items = [{"docid":"8772fe3a-6811-43dd-9ac4-f390be3f20e3","elementid":"134b8ce5-f118-4129-b3d9-f068cf0ea0e6","modelid":"65e31c6f-e8e5-4aee-b4d6-ac1217af4279"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {

# %%
# You don't need to write anything here
states = []
lons = []
lats = []
# The sample data is in a slightly difficult format, so we will change it to be in an easier format to work with
# We don't mind about the State being repeated, as long as we have all the latitudes and longitudes
#     Lat       Lon         State
# 0	-82.88318	-82.88318	FL
# 1	-82.87484	-82.87484	FL
# 2	-82.86562	-82.86562	FL

for s in us_states:
    # The amount of longitudes is the same as the latitudes, so this is safe
    # Iterate through each lat/lon pair

    for data in range(len(us_states[s]['lons'])):
        states.append(s)
        lons.append(us_states[s]['lons'][data])
        lats.append(us_states[s]['lats'][data])


# We created 3 lists of equal length, now we create a 
df = pd.DataFrame({'state': states, 'lat': lats, 'lon': lons})#dict(state=states, lon=lons, lat=lats))
df.head()

# Question - for the same state we can have multiple latitudes and longitudes, what impact (if any) do you
# think this may have on the visualisation process?
# Out:
#         lat       lon state
# 0  47.27588 -89.96571    MI
# 1  47.29110 -89.95710    MI
# 2  47.30654 -89.94697    MI
# 3  47.35284 -89.91657    MI
# 4  47.36828 -89.90644    MI

# %% [markdown]
# Now we have the data set up into two data frames: One with the lat/lng co-ordinates of the borders of states in the USA, the other with the winner of that state in the 2016 US Presidental election.
#
# We have seen what the geographical data look like, now display the first few rows of data about the winners using the variable `election_winners`:

# %%
# YOUR CODE HERE
election_winners.head()
# Out:
#   state   winner
# 0    AK    trump
# 1    MI    trump
# 2    ME  clinton
# 3    PA    trump
# 4    NY  clinton

# %%
type(election_winners)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# To work with the `Tile` we used, we need to include `x` and `y` columns in Web Mercator format.  In the cell below, modify the dataset as follows:
#
# - Call the `wgs84_to_web_mercator` function to add extra columns `x` and `y` to the `DataFrame`

# %%
# YOUR CODE HERE
df = wgs84_to_web_mercator(df, 'lon', 'lat')
df.head()
# Out:
#         lat       lon state             x             y
# 0  47.27588 -89.96571    MI -1.001494e+07  5.987222e+06
# 1  47.29110 -89.95710    MI -1.001398e+07  5.989719e+06
# 2  47.30654 -89.94697    MI -1.001285e+07  5.992254e+06
# 3  47.35284 -89.91657    MI -1.000947e+07  5.999858e+06
# 4  47.36828 -89.90644    MI -1.000834e+07  6.002395e+06

# %% [markdown]
# Using the election dataset, we now want to add an extra column to the `DataFrame` to give the colour of the state depending on the victor.  We are going to set the state to blue if Clinton won it, or red if Trump won it.
#
# To do this, we are going to use **[`loc`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html)**.  This specifies criteria for which rows we are to select, and then provides the name of a column to include the output:

# %%
# You don't need to write anything here
for e in range(len(election_winners)):
    winner = election_winners['winner'][e]
    colour = ''
    if winner == 'clinton':
        colour = 'blue'
    else:
        colour = 'red'

election_winners.loc[election_winners['winner'] == 'clinton', 'colour'] = 'blue'
election_winners.loc[election_winners['winner'] == 'trump', 'colour'] = 'red'
election_winners.head()
# Out:
#   state   winner colour
# 0    AK    trump    red
# 1    MI    trump    red
# 2    ME  clinton   blue
# 3    PA    trump    red
# 4    NY  clinton   blue

# %% [markdown]
# Now we can start using our data to overlay [`Glyphs`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html) onto a map.  We will start by creating a new map centred over the USA.  Create a new map with the same attributes as the previous map you created.  Call the `Figure` variable `fig`.

# %%
# YOUR CODE HERE
USA = x_range,y_range = ((-13884029,-7453304), (2698291,6455972))

url = 'http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png'
attribution = "Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL"

fig = Figure(tools='pan, wheel_zoom', x_range=x_range, y_range=y_range)
fig.axis.visible = False
fig.add_tile(WMTSTileSource(url=url, attribution=attribution))
# Out:
# TileRenderer(id='5682e72a-809f-46e9-ba73-76e96580a444', ...)

# %% [markdown]
# Now try and add a `Glpyh` to the `Figure` which gives the outline of California, and colours it in blue.  Use the same strategy as you used above for the line graph.  The glyph in question is [`Patch`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#patch-glyphs), which uses the function `patch`.

# %%
# YOUR CODE HERE
data = df.loc[df['state'] == 'CA']
colour = election_winners.loc[election_winners['state'] == 'CA']['colour'].iloc[0]
ca = fig.patch(data['x'], data['y'], fill_color=colour)

# %% [markdown]
# Now we can show the map of the USA with the California Glyph:

# %%
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a4ce0150-d2cf-445a-a2f9-b1e6ec50b70f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a4ce0150-d2cf-445a-a2f9-b1e6ec50b70f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a4ce0150-d2cf-445a-a2f9-b1e6ec50b70f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a4ce0150-d2cf-445a-a2f9-b1e6ec50b70f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8d1d10e4-f2dc-44a6-860c-66d6a169430e":{"roots":{"references":[{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8a6eefbb-164a-4788-838b-68430827cecf","type":"Patch"},{"attributes":{"plot":null,"text":""},"id":"885df729-9435-4df3-b57c-f48d40aaa48c","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"dcd62187-459c-4728-8d1f-5576122ee1d6","subtype":"Figure","type":"Plot"},"ticker":{"id":"732252fa-0469-4f49-9738-28139a980b5e","type":"BasicTicker"}},"id":"45441274-b916-421c-8057-7fb33b2a5e57","type":"Grid"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.
['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 
                  'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 
                  'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 
                  'VT', 'VA', 'WA', 'WV', 'WI', 'WY']


# Making a copy of a subset of the original data.  This way, if we make a change, it doesn't affect the original
data = df.loc[df['state'] == 'CA'].copy()
# We're using the patch glyph to colour fill the states
# The .iloc[0] signifies the first row in the dataset, because we only need one colour here

ca = fig.patch(data['x'], data['y'], fill_color=colour)

show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="668400ca-2a1a-45de-9fe2-b7f47b2d35e2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("668400ca-2a1a-45de-9fe2-b7f47b2d35e2").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("668400ca-2a1a-45de-9fe2-b7f47b2d35e2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '668400ca-2a1a-45de-9fe2-b7f47b2d35e2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2a6f3548-fd0b-478c-8bd7-afe225cfb571":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[759]},"y":{"__ndarray__":"...","dtype":"float64","shape":[759]}}},"id":"e63c152f-e55f-48d6-b32c-284ab41433d1","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e63c152f-e55f-48d6-b32c-284ab41433d1","type":"ColumnDataSource"},"glyph":{"id":"5e5ae782-34a6-43d9-a32e-5f8f1ec275a6","type":"Patch"},"hover_glyph":null,"nonselection_glyph":{"id":"c3492388-d0cf-4fe7-b91e-1f589025f7ff","type":"Patch"},"selection_glyph":null},"id":"24ad4293-4c78-46fb-b238-fec262467344","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8a6eefbb-164a-4788-838b-68430827cecf","type":"Patch"},{"attributes":{"plot":null,"text":""},"id":"885df729-9435-4df3-b57c-f48d40aaa48c","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"dcd62187-459c-4728-8d1f-5576122ee1d6","subtype":"Figure","type":"Plot"},"ticker":{"id":"732252fa-0469-4f49-9738-28139a980b5e","type":"BasicTicker"}},"id":"45441274-b916-421c-8057-7fb33b2a5e57","type":"Grid"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"bdfcb679-84df-4cac-886c-9b9a9108ece2","type":"WMTSTileSource"},{"attributes":{"plot":{"id":"dcd62187-459c-4728-8d1f-5576122ee1d6","subtype":"Figure","type":"Plot"}},"id":"6c5cc618-a478-426a-bdff-02159b03a053","type":"PanTool"},{"attributes":{"formatter":{"id":"f27b0833-f146-4f70-b9bf-c2c7430b8098","type":"BasicTickFormatter"},"plot":{"id":"dcd62187-459c-4728-8d1f-5576122ee1d6","subtype":"Figure","type":"Plot"},"ticker":{"id":"bba5c197-9771-4456-a7e8-d86f061ae80a","type":"BasicTicker"},"visible":false},"id":"981f3c17-1ef9-41f3-b9f5-695f7d83ada6","type":"LinearAxis"},{"attributes":{"below":[{"id":"981f3c17-1ef9-41f3-b9f5-695f7d83ada6","type":"LinearAxis"}],"left":[{"id":"bd5792d3-240e-473f-b131-e01e827c0edf","type":"LinearAxis"}],"renderers":[{"id":"981f3c17-1ef9-41f3-b9f5-695f7d83ada6","type":"LinearAxis"},{"id":"267346d8-e9e6-4bb8-b796-ed9417876b54","type":"Grid"},{"id":"bd5792d3-240e-473f-b131-e01e827c0edf","type":"LinearAxis"},{"id":"45441274-b916-421c-8057-7fb33b2a5e57","type":"Grid"},{"id":"5682e72a-809f-46e9-ba73-76e96580a444","type":"TileRenderer"},{"id":"33b7bd8d-7695-4411-a407-dc56c1443ad7","type":"GlyphRenderer"},{"id":"24ad4293-4c78-46fb-b238-fec262467344","type":"GlyphRenderer"}],"title":{"id":"885df729-9435-4df3-b57c-f48d40aaa48c","type":"Title"},"tool_events":{"id":"e7b8e7c3-e517-4753-98dc-1efb8191b53d","type":"ToolEvents"},"toolbar":{"id":"fad121f9-a6d9-45f5-acc7-a3d762f12751","type":"Toolbar"},"x_range":{"id":"ed0a78ad-f1c9-41fd-b0ee-e40e5a361c80","type":"Range1d"},"y_range":{"id":"66c6f786-aea1-4f19-897e-9675a598176e","type":"Range1d"}},"id":"dcd62187-459c-4728-8d1f-5576122ee1d6","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e5ae782-34a6-43d9-a32e-5f8f1ec275a6","type":"Patch"},{"attributes":{},"id":"e7b8e7c3-e517-4753-98dc-1efb8191b53d","type":"ToolEvents"},{"attributes":{"tile_source":{"id":"bdfcb679-84df-4cac-886c-9b9a9108ece2","type":"WMTSTileSource"}},"id":"5682e72a-809f-46e9-ba73-76e96580a444","type":"TileRenderer"},{"attributes":{},"id":"f27b0833-f146-4f70-b9bf-c2c7430b8098","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"b8bb8786-b3f5-4214-a093-e776c05cba9a","type":"BasicTickFormatter"},"plot":{"id":"dcd62187-459c-4728-8d1f-5576122ee1d6","subtype":"Figure","type":"Plot"},"ticker":{"id":"732252fa-0469-4f49-9738-28139a980b5e","type":"BasicTicker"},"visible":false},"id":"bd5792d3-240e-473f-b131-e01e827c0edf","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"lin ...

# %% [markdown]
# ## Putting it all Together
#
# Now we have built individual components which we can modify to generate our interactive visualisation.  To put them together, we will:
#
# - Create and display a widget which allows text to be entered to select a state
# - Create a function for them to call which will modify the selected regions on the map
# - Display the map
#
# First, we are going to try and generalise the code we saw above into one which works for all states into the function `callback`, and display a new map.

# %%
ca.data_source.to_df()
# Out:
#                  x             y
# 1711 -1.369242e+07  4.547274e+06
# 1712 -1.369202e+07  4.547095e+06
# 1713 -1.369175e+07  4.546863e+06
# 1714 -1.369090e+07  4.546122e+06
# 1715 -1.369023e+07  4.545425e+06
# 1716 -1.368980e+07  4.544870e+06
# 1717 -1.368956e+07  4.544532e+06
# 1718 -1.368941e+07  4.544159e+06
# 1719 -1.368932e+07  4.543979e+06
# 1720 -1.368901e+07  4.543862e+06
# 1721 -1.368865e+07  4.543648e+06
# 1722 -1.368830e+07  4.543364e+06
# 1723 -1.368796e+07  4.543036e+06
# 1724 -1.368767e+07  4.542723e+06
# 1725 -1.368725e+07  4.542315e+06
# 1726 -1.368673e+07  4.541662e+06
# 1727 -1.368623e+07  4.540694e+06
# 1728 -1.368587e+07  4.540096e+06
# 1729 -1.368559e+07  4.539292e+06
# 1730 -1.368539e+07  4.538534e+06
# 1731 -1.368536e+07  4.538432e+06
# 1732 -1.368516e+07  4.537478e+06
# 1733 -1.368514e+07  4.536797e+06
# 1734 -1.368532e+07  4.535856e+06
# 1735 -1.368551e+07  4.535239e+06
# 1736 -1.368558e+07  4.534649e+06
# 1737 -1.368577e+07  4.533838e+06
# 1738 -1.368618e+07  4.532880e+06
# 1739 -1.368663e+07  4.531981e+06
# 1740 -1.368727e+07  4.531274e+06
# ...            ...           ...
# 2440 -1.338060e+07  5.160145e+06
# 2441 -1.335845e+07  5.160251e+06
# 2442 -1.335825e+07  5.160162e+06
# 2443 -1.335825e+07  5.157842e+06
# 2444 -1.335834e+07  5.051866e+06
# 2445 -1.335826e+07  4.993088e+06
# 2446 -1.335786e+07  4.923830e+06
# 2447 -1.335804e+07  4.878933e+06
# 2448 -1.335839e+07  4.836294e+06
# 2449 -1.335851e+07  4.804781e+06
# 2450 -1.335902e+07  4.775612e+06
# 2451 -1.335553e+07  4.719031e+06
# 2452 -1.333167e+07  4.697960e+06
# 2453 -1.329545e+07  4.665824e+06
# 2454 -1.324713e+07  4.622415e+06
# 2455 -1.319328e+07  4.573868e+06
# 2456 -1.316127e+07  4.544604e+06
# 2457 -1.314059e+07  4.525672e+06
# 2458 -1.311295e+07  4.500216e+06
# 2459 -1.305987e+07  4.450879e+06
# 2460 -1.301016e+07  4.404396e+06
# 2461 -1.295484e+07  4.351936e+06
# 2462 -1.292205e+07  4.320698e+06
# 2463 -1.290139e+07  4.300869e+06
# 2464 -1.287436e+07  4.274826e+06
# 2465 -1.284292e+07  4.244397e+06
# 2466 -1.281468e+07  4.216729e+06
# 2467 -1.278176e+07  4.184749e+06
# 2468 -1.276096e+07  4.164146e+06
# 2469 -1.276094e+07  4.164134e+06
#
# [759 rows x 2 columns]

# %%
def callback(state):
    # Filter the data here from `df` using `loc` to get the individual state
    # Then, access the data_source of `ca` to change it to the new data
    # YOUR CODE HERE
    data = df.loc[df['state'] == state]
    ca.data_source.data['x'] = data['x']
    ca.data_source.data['y'] = data['y']
    
    # Get the colour of the new state, and update the fill_color of the glyph    
    colour = election_winners.loc[election_winners['state'] == state]['colour'].iloc[0]
    ca.glyph.fill_color = colour
    # Update the map
    # YOUR CODE HERE
    push_notebook()
    
fig = Figure(tools='pan, wheel_zoom', x_range=x_range, y_range=y_range)
fig.axis.visible = False
fig.add_tile(WMTSTileSource(url=url, attribution=attribution))
ca = fig.patch(data['x'], data['y'], fill_color=colour)    
show(fig, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fa2ec15c-4124-4ff5-91e1-031ebd100865"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fa2ec15c-4124-4ff5-91e1-031ebd100865").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("c3eda15a-438a-42a5-a33b-5f0b14386ae2", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fa2ec15c-4124-4ff5-91e1-031ebd100865");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fa2ec15c-4124-4ff5-91e1-031ebd100865' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d0019d47-27c9-4867-a5bc-61ed4af7a381":{"roots":{"references":[{"attributes":{"plot":{"id":"19c1b16c-7cb6-433d-9b69-6c620a347716","subtype":"Figure","type":"Plot"}},"id":"1eede318-3a43-41ea-8c4e-86fca922a0a3","type":"WheelZoomTool"},{"attributes":{},"id":"0c9ad47a-df0f-4643-b33d-da7b1390dee0","type":"BasicTicker"},{"attributes":{"plot":{"id":"19c1b16c-7cb6-433d-9b69-6c620a347716","subtype":"
type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[759]},"y":{"__ndarray__":"...","dtype":"float64","shape":[759]}}},"id":"6c784c6e-1cd3-4d1c-aee4-88e65a9030f0","type":"ColumnDataSource"},{"attributes":{},"id":"d79ba69a-b078-474c-a509-8340e4dd5e1a","type":"BasicTicker"},{"attributes":{},"id":"307119a9-e529-4a3c-9f02-5a4dfa7a98ed","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"955076f6-06a1-40d3-b88d-a30ac150fd9e","type":"BasicTickFormatter"},"plot":{"id":"19c1b16c-7cb6-433d- ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[24]</strong>&gt;</code></p>

# %% [markdown]
# Now we'll add a text box interactive widget, so that by entering a state we can see the map update.  This still uses the `interactive` function, except the parameter to the `callback` function is a string rather than a number.
#
# The response to the call for interactive is being assigned to a variable - in this case `i` - to later use.

# %%
# You don't need to write anything here
i = interactive(callback, state='')
i
# Out:
# /opt/conda/lib/python3.5/site-packages/bokeh/models/sources.py:81: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-9c17acf398cc> in callback(state)
#       8
#       9     # Get the colour of the new state, and update the fill_color of the glyph
# ---> 10     colour = election_winners.loc[election_winners['state'] == state]['colour'].iloc[0]
#      11     ca.glyph.fill_color = colour
#      12     # Update the map
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1626
#    1627                 # validate the location
# -> 1628                 self._is_valid_integer(key, axis)
#    1629
#    1630             return self._get_loc(key, axis=axis)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1540         l = len(ax)
#    1541         if key >= l or key < -l:
# -> 1542             raise IndexError("single positional indexer is out-of-bounds")
#    1543         return True
#    1544
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ## Layout
#
# Finally, the widgets need to be set out.  Both Jupyter and Bokeh have their own widgets for layout, and they are not yet compatible.  To lay them out, we suggest that you keep the plot in one cell, and the widgets in the cell above or below.
#
# The functions `VBox` and `HBox` allow widgets to be laid out in a way which they align either vertically (for `VBox`) or horizontally (for `HBox`).  The function takes a list of `ipywidgets` widgets:

# %%
HBox(
    # We can put HBox and VBox inside each other as well 
    [ HBox([i, i]), VBox([i,i, i]) ]
)
    
    # Note - we may get an error warning message here as an indexer is out of bounds, why might that be?
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-9c17acf398cc> in callback(state)
#       8
#       9     # Get the colour of the new state, and update the fill_color of the glyph
# ---> 10     colour = election_winners.loc[election_winners['state'] == state]['colour'].iloc[0]
#      11     ca.glyph.fill_color = colour
#      12     # Update the map
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1626
#    1627                 # validate the location
# -> 1628                 self._is_valid_integer(key, axis)
#    1629
#    1630             return self._get_loc(key, axis=axis)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1540         l = len(ax)
#    1541         if key >= l or key < -l:
# -> 1542             raise IndexError("single positional indexer is out-of-bounds")
#    1543         return True
#    1544
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# Have a look at the list of widgets on the [ipywidgets documentation](http://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html) and experiment with displaying those in the cell below:

# %%
# YOUR CODE HERE
