# %% [markdown]
# # Data Analysis - Due 05th August (23:59)
#
#
# In this assessment, we will use the Python libraries `Pandas` and `NumPy` to perform basic operations on the data relating to food hygiene in Wandsworth.  In addition we will also perform linear regression on data about vehicle mileage and price.
#
# Run the cell below each time you load the page to make sure that all the imports are done correctly

# %%
import numpy as np
import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.charts import *
output_notebook()

from nose.tools import *

import pymongo
from pymongo import MongoClient
client = MongoClient('mongodb://cpduser:M13pV5woDW@mongodb/health_data', 27017)
db = client.health_data

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

print('All libraries successfully loaded')

# Create a simple bar chart with made up data
bar_chart = Bar(pd.Series([8,6,2,7,9,3]))
# Display the bar chart
show(bar_chart)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9756a6cf-d27c-457c-9c66-07ce85ed2594">Loading BokehJS ...</span>
#     </div>
# All libraries successfully loaded
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b97f5487-a7e1-48e8-b36b-c67cb9a98776"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b97f5487-a7e1-48e8-b36b-c67cb9a98776").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b97f5487-a7e1-48e8-b36b-c67cb9a98776");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b97f5487-a7e1-48e8-b36b-c67cb9a98776' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"38499f6e-2e14-438f-9491-328d3c001832":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"529790a0-b875-46af-a385-20e82da8c00c","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e779f2ef-1d87-4b71-81d6-a830e00a108d","type":"Rect"},{"attributes":{"formatter":{"id":"ae0d379f-1370-478a-842b-d8c82866d43b","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"155d350b-5343-43cd-85a2-95da921d65e0","subtype":"Chart","type":"Plot"},"ticker":{"id":"ce0aeee2-6f8a-4663-a0e1-da21bb39c4f9","type":"CategoricalTicker"}},"id":"61eb4195-5195-4769-9cdb-8b33fe284997","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4033be73-9df2-4aae-9688-0f3605572b14","type":"Rect"},{"attributes":{"label":{"value":"1"},"renderers":[{"id":"42a52a42-ee44-457f-ad37-b588d90f254b","type":"GlyphRenderer"}]},"id":"235eedd3-2b9d-4380-888f-468b0c8f3f8b","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"26a7214c-b5cb-430c-bd5b-20dc4e6035bd","type":"Rect"},{"attributes":{"dimension":1,"plot":{"id":"155d350b-5343-43cd-85a2-95da921d65e0","subtype":"Chart","type":"Plot"},"ticker":{"id":"6952c900-367c-4764-a243-62c13f98bd5b","type":"BasicTicker"}},"id":"4372ef6a-b5e6-4d08-b6de-8f2ab019b8fb","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9a3cf916-67df-4d00-844c-3bd6614a4a34","type":"Rect"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"b52156f6-4efe-4821-b675-cff8eedbfb38","type":"GlyphRenderer"}]},"id":"b048924b-4fa7-4b4e-9955-4060cbe85f1e","type":"LegendItem"},{"attributes":{"label":{"value":"2"},"renderers":[{"id":"71e7f649-376f-4227-ac1b-e1366ff30980","type":"GlyphRenderer"}]},"id":"166edfbf-c572-4c44-886f-fd7bd8511a4c","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["label","line_color","height","width","line_alpha","fill_alpha","y","x","color"],"data":{"chart_index":[{"index":0}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[8.0],"index":[0],"label":[{"index":0}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["0"],"y":[4.0]}},"id":"f52a5548-f991-4b91-b42b-e08d50bd7c8c","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"b048924b-4fa7-4b4e-9955-4060cbe85f1e","type":"LegendItem"},{"id":"235eedd3-2b9d-4380-888f-468b0c8f3f8b","type":"LegendItem"},{"id":"166edfbf-c572-4c44-886f-fd7bd8511a4c","type":"LegendItem"},{"id":"454d8110-3431-44c7-8741-f43edd362a0d","type":"LegendItem"},{"id":"663cc364-df43-4873-a3ea-90be40fd32a6","type":"LegendItem"},{"id":"8464a807-d056-4407-ab0f-4f324a409db5","type":"LegendItem"}],"location":"top_left","plot":{"id":"155d350b-5343-43cd-85a2-95da921d65e0","subtype":"Chart","type":"Plot"}},"id":"cef5f2c4-daa7-4100-ab16-2fb9644c8750","type":"Legend"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e273aae0-2fc0-4a53-9dbd-dfeecac3ae18","type": ...

# %% [markdown]
# ## Question 1: Statistics
#
# ### Question 1(a) [4 marks]
#
# Create a **function** `evaluate_random_data` which has the following **parameters**:
# - `n` the size of the Pandas `Series` you are to create
# - `evaluation` a string should say which task to perform on the `Series` object.
# - `seed` an integer which should instantiate a numpy `RandomState` instance, with a default value of 543210
#
# The function should do the following:
# - Create an array of size `n` which is full of random numbers integers between 0 and 100 (inclusive)
# - The `evaluation` should be able to perform mean, median and standard deviation functions on the created array
# - The function should **return** the output of the evaluation on the array.  It should be able to cope with `"mean"`, `"median"` and `"std"` (standard deviation).
#
# *Hint: Week 4, Guided Exercise 2, Randomness - Importing Data - Bokeh Charts*

# %%
def evaluate_random_data(n, evaluation, seed=543210):
    # YOUR CODE HERE

    rs = np.random.RandomState(seed)
    listy = []
    for var in range(n):
        listy.append(rs.randint(0, 101))
    
    df = pd.Series(listy)
    
    if evaluation == 'mean':
        return df.mean()
    elif evaluation == 'median':
        return df.median()
    elif evaluation == 'std':
        return df.std()
    else:
        return None
    
    raise NotImplementedError()

# %%
# Check a RandomState object is instantiated
tmp_rs = np.random.RandomState
del np.random.RandomState

try:
    evaluate_random_data(100, 'mean')
except AttributeError:
    print('The function correctly uses RandomState')
else:
    raise AssertionError('The function does not use RandomState')
finally:
    np.random.RandomState = tmp_rs

    
assert_equal(evaluate_random_data(100, 'mean', 511419), 47.39)
assert_equal(evaluate_random_data(100, 'mean', 364235), 48.45)

assert_equal(evaluate_random_data(100, 'median', 511419), 46)
assert_equal(evaluate_random_data(100, 'median', 364235), 44)

output = evaluate_random_data(100, 'std', 511419)
"{0:.4f}".format(round(output,4))
assert_equal("{0:.4f}".format(round(output,4)), '29.2968')

output = evaluate_random_data(100, 'std', 364235)
"{0:.4f}".format(round(output,4))
assert_equal("{0:.4f}".format(round(output,4)), '30.5159')

print('All tests successfully passed')
# Out:
# The function correctly uses RandomState
# All tests successfully passed

# %% [markdown]
# ### Question 1(b) [3 marks]
#
# The function `get_data` (provided) returns a Pandas `Series` for the given collection.  Using data from this function, and the PyMongo `collection_names` function, write a function `get_means` which takes the mean `RatingValue` from the first `n` collections in the `collection_names()` function.
#
# - You should **sort** `collection_names` in ascending alphabetical order.  Note that this is a Python `list` rather than a `Cursor`, so use **[this guide to sorting lists](https://wiki.python.org/moin/HowTo/Sorting)** to help you
# - The function should **return** a **Pandas `Series` object**, with a **name** of **`RatingValueMeans`**.
# - You should use the function from Question 1(a) to get a `Series` object of the `RatingValue`, and **obtain the mean** from that object
# - N.B. Be very careful you properly exit your loop!
#
# *Hint: Week 3, Guided Exercise 4, Cursors*
# *Hint: Week 4, Guided Exercise 2, Importing Data - Bokeh Charts*

# %%
def get_data(collection):
    cursor = collection.find()
    rating_values = pd.DataFrame(list(cursor))['RatingValue']
    return rating_values

def get_means(n):
    # YOUR CODE HERE
    
    var = 0
    listy = []
    
    for m in sorted(db.collection_names()):
        if var >= n:
            break
        var += 1 
        
        listy.append(get_data(db[m]).mean()) 
        
    return pd.Series(listy, name = 'RatingValueMeans')
    
    raise NotImplementedError()
    
#means = get_means(10)
#means
#type(means)

# %%
# You don't need to write anything here
means = get_means(10)

assert_equal(type(means), pd.Series)
assert_equal(len(means), 10)
assert_equal(round(means.sum(), 4), 27.2436)
means = get_means(12)
assert_equal(len(means), 12)
assert_equal(round(means.sum(), 4), 36.2604)
print('All tests passed successfully')
# Out:
# All tests passed successfully

# %% [markdown]
# ### Question 1(c) [4 marks]
#
# Create a function `get_sample_mean_distribution` which **returns** a series of the distribution of sample means of the `RatingValue` of the data from a given series.  The function should be defined as follows:
# - `data`: A `Series` object of the mean ratings of establishments
# - `n`: integer, the size of the sample
# - `m=1000`: integer, the amount of times to repeat the procedure
# - `seed=543210`: integer, default value 543210.  This should set a [`RandomState`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.RandomState.html) instance to be initialised with this value as an argument.
# - You should use the Pandas [`sample`](http://pandas.pydata.org/pandas-docs/version/0.19.2/generated/pandas.DataFrame.sample.html) function to generate your samples.
#
# The function should **return** the output as a **Pandas `Series` object**.
#
# *Hint: Week 4, Guided Exercise 2, Randomness*

# %%
# code test cell
listy = []
m = 1000
n = 20
seed = 543210
var = np.random.RandomState(seed)
data = pd.Series([5, 5, 5, 5, 5, 4, 5, 4, 5, 4, 5, 5, 3, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 4, 2, 4, 5, 5, 4, 5])
count = 0
#30 ints in the series

#calculate the mean of the sample m times return a list

while count < m:
    samp = data.sample(n, random_state=var).mean()
    listy.append(samp)
    count += 1

#print(pd.Series(listy))

# %%
def get_sample_mean_distribution(data, n, m=1000, seed=543210):
    # YOUR CODE HERE
    
    var = np.random.RandomState(seed)
    listy = []
    count = 0
    #calculate the mean of the sample m times return a list
    while count < m:
        samp = data.sample(n, random_state=var).mean()
        listy.append(samp)
        count += 1
    
    return pd.Series(listy)
        
    raise NotImplementedError()

#data = pd.Series([5, 5, 5, 5, 5, 4, 5, 4, 5, 4, 5, 5, 3, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 4, 2, 4, 5, 5, 4, 5])    
#get_sample_mean_distribution(data, 20, 1000, 123456)

# %%
# You don't need to write anything here
m = 1000
n = 20
data = pd.Series([5, 5, 5, 5, 5, 4, 5, 4, 5, 4, 5, 5, 3, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 4, 2, 4, 5, 5, 4, 5])
seed = 123456
actual_output = get_sample_mean_distribution(data, n, m, seed)

assert_equal(len(actual_output), 1000)
assert_equal(round(actual_output.sum(),4), 4528.6)

# Check randomness is working:
# The same seed should lead to the same result
seed_test_equal = get_sample_mean_distribution(data, n, m, seed)
assert_equal(actual_output.mean(), seed_test_equal.mean())

# A different seed should not be equal
seed_test_not_equal = get_sample_mean_distribution(data, n, m, 54321)
assert_not_equal(actual_output.mean(), seed_test_not_equal.mean())

print('All tests successfully passed')
# Out:
# All tests successfully passed

# %% [markdown]
# ### Question 1(d) [2 marks]
#
# Using the output from Question 1(c), **plot a histogram** illustrating the distribution, and **return** the histogram as the output of the function `plot_sample_mean_distribution`.
#
# This function should take the same parameters as the `get_sample_mean_distribution`, so that it can call that function to obtain the data.  The histogram should have **10 bins**.
#
# *Hint: Week 1, Guided Exercise 1, Python Primer*
# *Hint: Week 2, Guided Exercise 2, Python for Data Science*
# *Hint: Week 4, Guided Exercise 2, IQR & Outliers - Bokeh Charts*
# *Hint: Week 4, Guided Exercise 3, Residual Analysis*

# %%
def plot_sample_mean_distribution(data, n, m=1000, seed=543210):
    # YOUR CODE HERE
  
    var = get_sample_mean_distribution(data, n)
    hist = Histogram(var , bins=10)
    show(hist)
    return hist
    
    raise NotImplementedError()
    
#data = pd.Series([5, 5, 5, 5, 5, 4, 5, 4, 5, 4, 5, 5, 3, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 4, 2, 4, 5, 5, 4, 5])
#plot_sample_mean_distribution(data, 20)

# %%
# You don't need to write anything here
data = pd.Series([5, 5, 5, 5, 5, 4, 5, 4, 5, 4, 5, 5, 3, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 4, 2, 4, 5, 5, 4, 5])

# assert_equal())
assert_equal(type(plot_sample_mean_distribution(data, 20)), Chart)
# Check Histogram
old_hist = Histogram
del Histogram

try:
    plot_sample_mean_distribution(data, 20)
except NameError:
    pass
else:
    raise AssertionError("The chart does not appear to be a Histogram")
finally:
    Histogram = old_hist
    del old_hist

print('All tests successfully passed')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="27e32b0b-1fb6-412a-af12-f4098b60e1fa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("27e32b0b-1fb6-412a-af12-f4098b60e1fa").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("27e32b0b-1fb6-412a-af12-f4098b60e1fa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '27e32b0b-1fb6-412a-af12-f4098b60e1fa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aca2da4e-0c9b-4a3d-8827-588d844b4dc1":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["label","line_color","height","width","line_alpha","fill_alpha","y","x","color"],"data":{"chart_index":["(4.650000, 4.700000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[90.0],"label":["(4.650000, 4.700000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05000000000000071],"x":["4.675000000000001"],"y":[45.0]}},"id":"6a29fcdf-2b39-4d27-bc6b-59ad865f1b7c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8cc54c84-ae52-465a-9c03-a002a6a3e7f6","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb8db0d0-9375-4109-83c2-0f3eb8d03105","type":"Rect"},{"attributes":{"data_source":{"id":"d7781802-7306-41ca-9d71-0cb271360c0b","type":"ColumnDataSource"},"glyph":{"id":"71f2953b-fc27-4f30-a081-5eadb0102c84","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6d8b90f4-ec48-4783-81b7-bd5a182d2370","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"2a7b0e1d-c106-4472-98bb-5e4c11415052","type":"ColumnDataSource"},"glyph":{"id":"0de94173-92e9-4947-b146-443dbae9da07","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"71e25953-ff6a-426d-adb0-396ba567d131","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0de94173-92e9-4947-b146-443dbae9da07","type":"Rect"},{"attributes":{"callback":null,"end":5.027500000000001,"start":4.072499999999999},"id":"478127aa-f04c-4f0c-bfb7-691dee4559e2","type":"Range1d"},{"attributes":{"plot":null,"text":null},"id":"85f0be78-a3f7-4b19-9424-eaa5fe331530","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3ae00cec-093b-44dd-9ff8-41cb12873f52","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","line_color","height","width","line_alpha","fill_alpha","y","x","color"],"data":{"chart_index":["(4.350000, 4.400000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(4.350000, 4.400000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.04999999999999982],"x":["4.375"],"y":[0.0]}},"id":"75cf6c23-3d9a-4257-84c7-65f6d1236fed","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"47b49a4e-d4d2-4ccc-91b5-50fdf61a8086","type":"BoxAnnotation"},{"attributes":{"axis_label":"a","formatter":{"id":"0438cbd1-1e6f-48c2-8662-6ece3ea71d46","type":"BasicTickFormatter"},"plot":{"id":"552cf658-2548-437b-9f3d-3782222fb4ae","subtype":"Chart","type":"Plot"},"ticker":{"id":"5248d991-04d4-4d01-a459-abc48dfb1f07","type":"BasicTicker"}},"id":"7616a9e5-ddef-41ce-987d-3bab7d2f8970","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["label","line_color","height","width","line_alpha","fill_alpha","y","x","color"],"data":{"chart_index":["(4.600000, 4.650000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(4.600000, 4. ...
# All tests successfully passed

# %% [markdown]
# ## Question 2: Linear Regression
#
# This question uses a different dataset in order to illustrate linear regression.  We'll use a dataset similar to the cars dataset given as an example in the videos.
#
# ### Question 2(a) [1 mark]
#
# Create a function `get_car_data` which uses the Pandas `read_csv` to import the data in the `cars.csv` file and **return** a `DataFrame` of the data (The `cars.csv` file is in the same directory in the notebook)
#
# *Hint: Week 4, Guided Exercise 3, Classification - Importing Data*

# %%
def get_car_data():
    # YOUR CODE HERE
    
    data = pd.read_csv('cars.csv')
    return data

    raise NotImplementedError()

# %%
# You don't need to write anything here
assert_equal(len(get_car_data()), 1155)
assert_equal(type(get_car_data()), pd.DataFrame)
print('All tests successfully passed')
# Out:
# All tests successfully passed

# %% [markdown]
# ### Question 2(b) [3 marks]
#
# Create a **function** `remove_outliers` which removes the outliers from the dataset according to the $lower - (1.5 * IQR)$ and $upper + (1.5 * IQR)$ rule.  The function should have the following parameters:
#
# - `data` a Pandas `DataFrame`
# - `field` a string, which will say for which of the fields in the `DataFrame` to locate and remove outliers
#
# The function should **return** the `DataFrame` without the outliers.
#
# *Hint: Week 4, Guided Exercise 2, IQR*
# *Hint: Week 4, Guided Exercise 3, Residual Analysis*

# %%
# code test cell
data = get_car_data()
data = pd.DataFrame(data)
isinstance(data, pd.DataFrame)
#data.head()

#first determine the upper and lower value to subset out
upper_var = data['Price'].quantile(0.75)
lower_var = data['Price'].quantile(0.25)
iqr = upper_var - lower_var
min_val = lower_var - (1.5 * iqr)
max_val = upper_var + (1.5 * iqr)
#now create a new dataset removing the min and max vals
new_data = data.loc[data['Price'] <= max_val]
new_data = new_data.loc[data['Price'] >= min_val]
#min_val = -2255
#max_val = 12545
new_data.shape
# Out:
# (1101, 5)

# %%
def remove_outliers(data, field):
    # YOUR CODE HERE
    
    data = pd.DataFrame(data)

    #first determine the upper and lower quantile values to subset out
    upper_var = data[field].quantile(0.75)
    lower_var = data[field].quantile(0.25)
    iqr = upper_var - lower_var
    min_val = lower_var - (1.5 * iqr)
    max_val = upper_var + (1.5 * iqr)
    
    #now create a new dataset removing the min and max vals
    new_data = data.loc[data[field] <= max_val]
    new_data = new_data.loc[data[field] >= min_val]
    
    return new_data

    raise NotImplementedError()

# %%
# You don't have to write anything here
data = get_car_data()

data = remove_outliers(data, 'Price')
assert_equal(data.count()['Price'], 1101)

data = remove_outliers(data, 'Mileage')
assert_equal(data['Mileage'].count(), 1100)

data = remove_outliers(data, 'Year')
assert_equal(data['Year'].count(), 1092)
print('All tests successfully passed')
# Out:
# All tests successfully passed

# %% [markdown]
# ### Question 2(c) [2 marks]
# Create a function `scatter_feature`, which generates a **scatter** plot of data.  The function should take two parameters: `data`, a `DataFrame` of the regression data, and `feature_name`, the column name of the feature to be used as a predictor variable.  The following should also be applied:
# - The **response** variable is the `Price` columnn
# - The function should return a **`Chart`** instance of the scatter plot.
#
# *Hint: Week 4, Guided Exercise 2, Bokeh Charts*

# %%
def scatter_feature(data, feature_name):
    """
    This function returns a scatter plot for the particular `feature_name` v Price
    `data` should be a `DataFrame`
    `feature_name` should be a string
    """
    # YOUR CODE HERE
    
    scatter = Scatter(data, x=feature_name, y='Price')
    #show(scatter) #show is used when calling on the scatter_feature function
    return scatter
    
    #raise NotImplementedError()
show(scatter_feature(data, 'Mileage'))
show(scatter_feature(data, 'Year'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="47a29851-6213-4db1-b7ef-6043d0286d14"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("47a29851-6213-4db1-b7ef-6043d0286d14").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("47a29851-6213-4db1-b7ef-6043d0286d14");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '47a29851-6213-4db1-b7ef-6043d0286d14' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4e6311e4-c120-40ed-b778-4f7d2cd47f3a":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"a7441552-60db-4563-8a4a-0ed3adb9446a","type":"Title"},{"attributes":{},"id":"f2b0b183-b466-4c37-8c9c-8f50cfe0520c","type":"ToolEvents"},{"attributes":{"axis_label":"Price","formatter":{"id":"38d3e7cf-7184-489f-965d-77b0ac783b84","type":"BasicTickFormatter"},"plot":{"id":"c9fcfcad-64b8-4958-bc21-9266d415884f","subtype":"Chart","type":"Plot"},"ticker":{"id":"e1d561b8-7f68-43c7-8929-99a091f5179f","type":"BasicTicker"}},"id":"22f9b81f-61de-4d8b-9b39-85a7bf491f93","type":"LinearAxis"},{"attributes":{"callback":null,"end":187500.0,"start":-16500.0},"id":"5135876c-bde8-4c0a-b063-5448e1f5646d","type":"Range1d"},{"attributes":{"plot":{"id":"c9fcfcad-64b8-4958-bc21-9266d415884f","subtype":"Chart","type":"Plot"}},"id":"1a5ffb47-0307-47ff-8abf-376bb2e2e4f5","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"6b946391-652b-4a52-8600-a64ddaeaba54","type":"Circle"},{"attributes":{},"id":"b48923c4-b70c-4534-9185-a43faaa3b8cd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c9fcfcad-64b8-4958-bc21-9266d415884f","subtype":"Chart","type":"Plot"},"ticker":{"id":"9164a9df-2cd1-463b-805a-3bba394e5a22","type":"BasicTicker"}},"id":"7b42d585-c752-4faf-9cb5-5965bf07b39e","type":"Grid"},{"attributes":{"overlay":{"id":"69cf0b0a-a892-4a54-bc5f-0790b7feed38","type":"BoxAnnotation"},"plot":{"id":"c9fcfcad-64b8-4958-bc21-9266d415884f","subtype":"Chart","type":"Plot"}},"id":"f21d016d-e4d3-45ea-91f9-c098d37e0b64","type":"BoxZoomTool"},{"attributes":{},"id":"9164a9df-2cd1-463b-805a-3bba394e5a22","type":"BasicTicker"},{"attributes":{},"id":"38d3e7cf-7184-489f-965d-77b0ac783b84","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"e6bf9dd9-c2e5-4620-82ec-ccc13f937656","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"22f9b81f-61de-4d8b-9b39-85a7bf491f93","type":"LinearAxis"}],"renderers":[{"id":"69cf0b0a-a892-4a54-bc5f-0790b7feed38","type":"BoxAnnotation"},{"id":"9b258a79-1315-43e9-8422-1c76655e356d","type":"GlyphRenderer"},{"id":"2294c2b2-363a-47a3-8f77-6125be9f51d6","type":"Legend"},{"id":"e6bf9dd9-c2e5-4620-82ec-ccc13f937656","type":"LinearAxis"},{"id":"22f9b81f-61de-4d8b-9b39-85a7bf491f93","type":"LinearAxis"},{"id":"7b42d585-c752-4faf-9cb5-5965bf07b39e","type":"Grid"},{"id":"1c95aa13-2329-41c5-b467-5c11312a26c3","type":"Grid"}],"title":{"id":"a7441552-60db-4563-8a4a-0ed3adb9446a","type":"Title"},"tool_events":{"id":"f2b0b183-b466-4c37-8c9c-8f50cfe0520c","type":"ToolEvents"},"toolbar":{"id":"5498f20f-e23e-4a9a-b41c-4004a8eae576","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"5135876c-bde8-4c0a-b063-5448e1f5646d","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"5feab845-6d7b-45a0-935d-00c8f191864f","type":"Range1d"}},"id":"c9fcfcad-64b8-4958-bc21-9266d415884f","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"b6846d9e-af5a-4f63-bf67-836b25f8c7c3","type":"ColumnDataSource"},"glyph":{"id":"6b946391-652b-4a52-8600-a64ddaeaba54","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9b258a79-1315-43e9-8422-1c76655e356d","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":13642.1,"start":-123.10000000000014},"id":"5feab845-6d7b-45a0-935d-00c8f191864f","type":"Range1d"},{"attributes":{"plot":{"id":"c9fcfcad-64b8-4958-bc21-9266d415884f","subtype":"Chart","type":"Plot"}},"id":"39e3552e-ae70-4e07-8a54-d48a0c03ff53","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"69cf0b0a- ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a8b6fe5d-c812-42bd-a22e-f26f7153fee0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a8b6fe5d-c812-42bd-a22e-f26f7153fee0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a8b6fe5d-c812-42bd-a22e-f26f7153fee0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a8b6fe5d-c812-42bd-a22e-f26f7153fee0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aca0a146-d375-45aa-b52b-3ef5c5e2f3bd":{"roots":{"references":[{"attributes":{},"id":"69b57736-d3ad-42d7-9a90-18155902ed0b","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":13642.1,"start":-123.10000000000014},"id":"987cfc45-9119-4470-b863-8eeaf356f45b","type":"Range1d"},{"attributes":{"plot":{"id":"b025effc-4c7f-466b-8b18-08c4aa233c52","subtype":"Chart","type":"Plot"}},"id":"df8dca2e-2b64-4ce5-bf2d-d013d2c7a02a","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"b025effc-4c7f-466b-8b18-08c4aa233c52","subtype":"Chart","type":"Plot"}},"id":"3a08efa5-19a3-4439-af14-86be006b01df","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"1b6d5880-2723-43cf-a2e5-a20d2df9ecf8","type":"Circle"},{"attributes":{"overlay":{"id":"26a4a7b4-cfdb-458b-8531-56e974d08a25","type":"BoxAnnotation"},"plot":{"id":"b025effc-4c7f-466b-8b18-08c4aa233c52","subtype":"Chart","type":"Plot"}},"id":"2d9a9170-b98c-4bb9-a35a-dca312a82bc7","type":"BoxZoomTool"},{"attributes":{"axis_label":"Year","formatter":{"id":"69b57736-d3ad-42d7-9a90-18155902ed0b","type":"BasicTickFormatter"},"plot":{"id":"b025effc-4c7f-466b-8b18-08c4aa233c52","subtype":"Chart","type":"Plot"},"ticker":{"id":"6d8ecc87-c39f-4a2d-bb48-092c959e6a4a","type":"BasicTicker"}},"id":"0ca5f739-94d5-4528-85ec-9de13861a224","type":"LinearAxis"},{"attributes":{"plot":{"id":"b025effc-4c7f-466b-8b18-08c4aa233c52","subtype":"Chart","type":"Plot"}},"id":"0a49a92b-f76e-46b4-97b4-8a4cf798df6e","type":"ResetTool"},{"attributes":{"callback":null,"end":2017.5,"start":1999.5},"id":"f4210a02-4edd-46c8-970e-cf45dc07eca9","type":"Range1d"},{"attributes":{},"id":"5217bc74-a3ab-4229-bcff-27045caca36a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b025effc-4c7f-466b-8b18-08c4aa233c52","subtype":"Chart","type":"Plot"}},"id":"803029ba-935f-4514-a450-0d208b3ac057","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9e9ff7f3-0054-44e9-a10f-684bd9a158b7","type":"PanTool"},{"id":"df8dca2e-2b64-4ce5-bf2d-d013d2c7a02a","type":"WheelZoomTool"},{"id":"2d9a9170-b98c-4bb9-a35a-dca312a82bc7","type":"BoxZoomTool"},{"id":"3a08efa5-19a3-4439-af14-86be006b01df","type":"SaveTool"},{"id":"0a49a92b-f76e-46b4-97b4-8a4cf798df6e","type":"ResetTool"},{"id":"803029ba-935f-4514-a450-0d208b3ac057","type":"HelpTool"}]},"id":"3c308567-4c97-423b-988b-b635b8faa0d2","type":"Toolbar"},{"attributes":{},"id":"fbb15d0c-f297-4716-93f5-ff48ce547549","type":"ToolEvents"},{"attributes":{"location":"top_left","plot":{"id":"b025effc-4c7f-466b-8b18-08c4aa233c52","subtype":"Chart","type":"Plot"}},"id":"669e425d-a2e8-4de4-b98d-7faef0c62978","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"26a4a7b4-cfdb-458b-8531-56e974d08a25","type":"BoxAnnotation"},{"attributes":{},"id":"48b01d16-ce6a-4b1f-bd77-3d2db71e5f76","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null, ...

# %% [markdown]
# ### Question 2(d) [3 marks]
#
# Using the `scikit-learn` libarary, write a function `split_data` which generates a **training** and a **test** dataset, based on features passed in as arguments.  The function should have three parameters:
#
# - **`data`** a `DataFrame` containing the data to be evaluated
# - **`features`** a list of strings which will be used to select the features from the dataset
# - **`seed`** an integer with default value `543210`, which  should be used to initialise a `RandomState` (as with Question 1(a),
# - The function should return the output of **[`train_test_split`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)**, using that `RandomState`, and data with the selected features from the `features` parameter.
# - The **test size** of the returned data should be **20%**
# - As with question 2c the **response** variable shuld be the **'Price'** columnn
#
# *Hint: Week 4, Guided Exercise 3, Training and Testing Data*

# %%
def split_data(data, features, seed=543210):
    # YOUR CODE HERE
    #used the module sklearn and function train_test_split
    
    X = data[features]
    y = data['Price'] 
    return train_test_split(X, y, test_size=0.2, random_state=np.random.RandomState(seed=seed))
    raise NotImplementedError()

#x1, x2, y1, y2 = split_data(data, ['Mileage'], 123456)
#x1.index[0]

# %%
# You don't need to write anything here
data = get_car_data()

x1, x2, y1, y2 = split_data(data, ['Mileage'])
assert_equal(len(x1), 924)
assert_equal(len(x2), 231)

assert_equal(x1.index[0], 607)
x1, x2, y1, y2 = split_data(data, ['Mileage'], 123456)
assert_equal(x1.index[0], 642)
print("All tests successfully passed")
# Out:
# All tests successfully passed

# %% [markdown]
# ### Question 2(e) [4 marks]
#
# Create a function `evaluate_model` to **fit** and **evaluate** the linear regression model using the test the accuracy of the model with different features using $R^2$.  The function should contain the same parameters as `split_data`, so it can call that function.
#
# The model should be evaluated based on the test data.
#
# *Hint: Week 2, Guided Exercise 2, Exercise 3a*
# *Hint: Week 4, Guided Exercise 3, Lineaar Regression - Fitting The Model - Residual Analysis*

# %%
lm = LinearRegression()
X_train, X_test, y_train, y_test = split_data(data, ['Year'], 511419)
model = lm.fit(X_train, y_train)
score = lm.score(X_test, y_test)
print(model, score)
print(round(score, 4))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False) 0.252556080999
# 0.2526

# %%
def evaluate_model(data, features, seed=543210):
    # YOUR CODE HERE
    
    lm = LinearRegression()
    X_train, X_test, y_train, y_test = split_data(data, features, seed)
    model = lm.fit(X_train, y_train)
    score = lm.score(X_test, y_test)
    return score
    
    raise NotImplementedError()

# %%
## You don't need to write anything here

data = get_car_data()

assert_equal(round(evaluate_model(data, ['Mileage'], 511419), 4),0.4742)
assert_equal(round(evaluate_model(data, ['Year'], 511419), 4), 0.2526)
assert_equal(round(evaluate_model(data, ['Year', 'Mileage'], 511419), 4), 0.4754)
print("All tests successfully passed")
# Out:
# All tests successfully passed
